# %% [markdown]
# # 2. 한국거래소 전체 종목 분석

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('krx.csv')

# %% [markdown]
# <br>
#
# ## 2.1 데이터 미리보기

# %%
df.head()
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S    특수 목적용 기계 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth      Representative                       HomePage Region
# 0         03월  박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1         12월                 이현우         http://www.ajnet.co.kr  서울특별시
# 2         12월   채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3         12월                 정기로   http://www.apsholdings.co.kr    경기도
# 4         12월                 김영주     http://www.apsystems.co.kr    경기도

# %%
# sample() : 랜덤하게 1개 리턴
df.sample()
# Out:
#       Symbol  Market  Name                 Sector Industry ListingDate  \
# 2593  205470  KOSDAQ  휴마시스  의료용품 및 기타 의약 관련제품 제조업   체외진단키트  2014-12-01
#
#      SettleMonth Representative                HomePage Region
# 2593         12월            차정학  http://www.humasis.com    경기도

# %% [markdown]
# <br>
#
# ## 2.2 데이터 요약하기

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2614 entries, 0 to 2613
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          2614 non-null   object
#  1   Market          2614 non-null   object
#  2   Name            2614 non-null   object
#  3   Sector          2411 non-null   object
#  4   Industry        2392 non-null   object
#  5   ListingDate     2411 non-null   object
#  6   SettleMonth     2411 non-null   object
#  7   Representative  2411 non-null   object
#  8   HomePage        2239 non-null   object
#  9   Region          2411 non-null   object
# dtypes: object(10)
# memory usage: 204.3+ KB

# %%
df.describe()
# Out:
#         Symbol  Market       Name         Sector Industry ListingDate  \
# count     2614    2614       2614           2411     2392        2411
# unique    2614       3       2614            158     2240        1777
# top     025980  KOSDAQ  GB중소성장기업I  특수 목적용 기계 제조업   기업인수합병  1996-07-03
# freq         1    1471          1            141       37           8
#
#        SettleMonth Representative                HomePage Region
# count         2411           2411                    2239   2411
# unique           9           2297                    2218     21
# top            12월            이재원  http://www.donga.co.kr  서울특별시
# freq          2351              4                       2    969

# %%
# 중복을 제외한 unique 값 확인
df.nunique()
# Out:
# Symbol            2614
# Market               3
# Name              2614
# Sector             158
# Industry          2240
# ListingDate       1777
# SettleMonth          9
# Representative    2297
# HomePage          2218
# Region              21
# dtype: int64

# %%
# index 값 보기
df.index
# Out:
# RangeIndex(start=0, stop=2614, step=1)

# %%
# 컬럼값 보기
df.columns
# Out:
# Index(['Symbol', 'Market', 'Name', 'Sector', 'Industry', 'ListingDate',
#        'SettleMonth', 'Representative', 'HomePage', 'Region'],
#       dtype='object')

# %%
# 값 보기
df.values
# Out:
# array([['060310', 'KOSDAQ', '3S', ..., '박종익, 김세완 (각자 대표이사)',
#         'http://www.3sref.com', '서울특별시'],
#        ['095570', 'KOSPI', 'AJ네트웍스', ..., '이현우',
#         'http://www.ajnet.co.kr', '서울특별시'],
#        ['006840', 'KOSPI', 'AK홀딩스', ..., '채형석, 이석주(각자 대표이사)',
#         'http://www.aekyunggroup.co.kr', '서울특별시'],
#        ...,
#        ['003280', 'KOSPI', '흥아해운', ..., '이환구', 'http://www.heung-a.com',
#         '서울특별시'],
#        ['037440', 'KOSDAQ', '희림', ..., '정영균, 이목운, 허철호, 염두성 (각자대표)',
#         'http://www.heerim.com', '서울특별시'],
#        ['238490', 'KOSDAQ', '힘스', ..., '김주환', 'http://www.hims.co.kr',
#         '인천광역시']], dtype=object)

# %%
pd.DataFrame(df.values)
# Out:
#            0       1        2                         3  \
# 0     060310  KOSDAQ       3S             특수 목적용 기계 제조업
# 1     095570   KOSPI   AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI    AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ   APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ    AP시스템             특수 목적용 기계 제조업
# ...      ...     ...      ...                       ...
# 2609  000547   KOSPI  흥국화재2우B                       NaN
# 2610  000545   KOSPI    흥국화재우                       NaN
# 2611  003280   KOSPI     흥아해운                    해상 운송업
# 2612  037440  KOSDAQ       희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 2613  238490  KOSDAQ       힘스             특수 목적용 기계 제조업
#
#                                    4           5    6  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23  03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21  12월
# 2                               지주사업  1999-08-11  12월
# 3                        인터넷 트래픽 솔루션  2001-12-04  12월
# 4                        디스플레이 제조 장비  2017-04-07  12월
# ...                              ...         ...  ...
# 2609                             NaN         NaN  NaN
# 2610                             NaN         NaN  NaN
# 2611                  외항화물운송업(케미컬탱커)  1976-06-29  12월
# 2612                       설계 및 감리용역  2000-02-03  12월
# 2613  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20  12월
#
#                               7                              8      9
# 0            박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1                           이현우         http://www.ajnet.co.kr  서울특별시
# 2             채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3                           정기로   http://www.apsholdings.co.kr    경기도
# 4                           김영주     http://www.apsystems.co.kr    경기도
# ...                         ...                            ...    ...
# 2609                        NaN                            NaN    NaN
# 2610                        NaN                            NaN    NaN
# 2611                        이환구         http://www.heung-a.com  서울특별시
# 2612  정영균, 이목운, 허철호, 염두성 (각자대표)          http://www.heerim.com  서울특별시
# 2613                        김주환          http://www.hims.co.kr  인천광역시
#
# [2614 rows x 10 columns]

# %% [markdown]
# <br>
#
# ## 2.3 데이터 색인하기

# %% [markdown]
# ### 2.3.1 `Series`

# %%
# 하나의 컬럼 가져오기
df["Name"]
# Out:
# 0            3S
# 1        AJ네트웍스
# 2         AK홀딩스
# 3        APS홀딩스
# 4         AP시스템
#          ...
# 2609    흥국화재2우B
# 2610      흥국화재우
# 2611       흥아해운
# 2612         희림
# 2613         힘스
# Name: Name, Length: 2614, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
# 첫 번째 행 데이터 가져오기
df.loc[0]
# Out:
# Symbol                          060310
# Market                          KOSDAQ
# Name                                3S
# Sector                   특수 목적용 기계 제조업
# Industry                   반도체 웨이퍼 캐리어
# ListingDate                 2002-04-23
# SettleMonth                        03월
# Representative      박종익, 김세완 (각자 대표이사)
# HomePage          http://www.3sref.com
# Region                           서울특별시
# Name: 0, dtype: object

# %%
type(df.loc[0])
# Out:
# pandas.core.series.Series

# %% [markdown]
# <br>
#
# ### 2.3.2 `DataFrame`

# %%
df
# Out:
#       Symbol  Market     Name                    Sector  \
# 0     060310  KOSDAQ       3S             특수 목적용 기계 제조업
# 1     095570   KOSPI   AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI    AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ   APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ    AP시스템             특수 목적용 기계 제조업
# ...      ...     ...      ...                       ...
# 2609  000547   KOSPI  흥국화재2우B                       NaN
# 2610  000545   KOSPI    흥국화재우                       NaN
# 2611  003280   KOSPI     흥아해운                    해상 운송업
# 2612  037440  KOSDAQ       희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 2613  238490  KOSDAQ       힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                               지주사업  1999-08-11         12월
# 3                        인터넷 트래픽 솔루션  2001-12-04         12월
# 4                        디스플레이 제조 장비  2017-04-07         12월
# ...                              ...         ...         ...
# 2609                             NaN         NaN         NaN
# 2610                             NaN         NaN         NaN
# 2611                  외항화물운송업(케미컬탱커)  1976-06-29         12월
# 2612                       설계 및 감리용역  2000-02-03         12월
# 2613  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20         12월
#
#                  Representative                       HomePage Region
# 0            박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1                           이현우         http://www.ajnet.co.kr  서울특별시
# 2             채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3                           정기로   http://www.apsholdings.co.kr    경기도
# 4                           김영주     http://www.apsystems.co.kr    경기도
# ...                         ...                            ...    ...
# 2609                        NaN                            NaN    NaN
# 2610                        NaN                            NaN    NaN
# 2611                        이환구         http://www.heung-a.com  서울특별시
# 2612  정영균, 이목운, 허철호, 염두성 (각자대표)          http://www.heerim.com  서울특별시
# 2613                        김주환          http://www.hims.co.kr  인천광역시
#
# [2614 rows x 10 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# 두 개 이상의 컬럼 가져오기 -> 각 컬럼명을 리스트 타입으로 지정
df[['Name', 'Symbol']]
# Out:
#          Name  Symbol
# 0          3S  060310
# 1      AJ네트웍스  095570
# 2       AK홀딩스  006840
# 3      APS홀딩스  054620
# 4       AP시스템  265520
# ...       ...     ...
# 2609  흥국화재2우B  000547
# 2610    흥국화재우  000545
# 2611     흥아해운  003280
# 2612       희림  037440
# 2613       힘스  238490
#
# [2614 rows x 2 columns]

# %%
type(df[['Name', 'Symbol']])
# Out:
# pandas.core.frame.DataFrame

# %%
# 두 개 이상의 행 가져오기 -> 각 인덱스를 리스트 타입으로 지정
df.loc[[0,1]]
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S    특수 목적용 기계 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
#
#   SettleMonth      Representative                HomePage Region
# 0         03월  박종익, 김세완 (각자 대표이사)    http://www.3sref.com  서울특별시
# 1         12월                 이현우  http://www.ajnet.co.kr  서울특별시

# %%
type(df.loc[[0, 1]])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Name']]
# Out:
#          Name
# 0          3S
# 1      AJ네트웍스
# 2       AK홀딩스
# 3      APS홀딩스
# 4       AP시스템
# ...       ...
# 2609  흥국화재2우B
# 2610    흥국화재우
# 2611     흥아해운
# 2612       희림
# 2613       힘스
#
# [2614 rows x 1 columns]

# %%
type(df[['Name']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# `df['Name']` : Series
# `df[['Name']]` : DataFrame

# %% [markdown]
# <br>
#
# ### 2.3.3 `loc`를 이용한 서브셋 가져오기

# %%
# df.loc[행, 열]
df.loc[0, 'Name']
# Out:
# '3S'

# %% [markdown]
# - 행, 열 접근은 다음과 같은 방식으로도 가능하다.
#   - `df['Name'][0]`
# - 하지만, 이 방식을 데이터프레임에 2번 접근하므로 비효율적이다.
# - 따라서, 행, 열 접근은 다음과 같은 방식이 효율적이다.
#   - `df.loc[0, 'Name']`

# %%
# 여러개의 행과 하나의 열
df.loc[[0, 1], 'Name']
# Out:
# 0        3S
# 1    AJ네트웍스
# Name: Name, dtype: object

# %%
# 하나의 행과 여러 개의 열
df.loc[0, ['Name', 'Symbol']]
# Out:
# Name          3S
# Symbol    060310
# Name: 0, dtype: object

# %%
# 여러개의 행과 여러개의 열
df.loc[[0,1], ['Name', 'Symbol']]
# Out:
#      Name  Symbol
# 0      3S  060310
# 1  AJ네트웍스  095570

# %% [markdown]
# <br>
#
# ### 2.3.4 boolean indexing
#
# - 특정 조건을 만족하는 서브셋 가져오기

# %%
df['Name'] == '카카오'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2609    False
# 2610    False
# 2611    False
# 2612    False
# 2613    False
# Name: Name, Length: 2614, dtype: bool

# %%
# 카카오 종목 정보
df[df['Name'] == '카카오']
# Out:
#       Symbol Market Name                            Sector         Industry  \
# 2009  035720  KOSPI  카카오  자료처리, 호스팅, 포털 및 기타 인터넷 정보매개 서비스업  인터넷 서비스(인터넷 광고)
#
#      ListingDate SettleMonth Representative                  HomePage   Region
# 2009  2017-07-10         12월       여민수, 조수용  http://www.kakaocorp.com  제주특별자치도

# %%
# 서울특별시 종목 정보
df[df['Region'] == '서울특별시']
# Out:
#       Symbol  Market    Name                    Sector  \
# 0     060310  KOSDAQ      3S             특수 목적용 기계 제조업
# 1     095570   KOSPI  AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI   AK홀딩스                    기타 금융업
# 5     211270  KOSDAQ    AP위성            통신 및 방송 장비 제조업
# 6     027410   KOSPI     BGF                    기타 금융업
# ...      ...     ...     ...                       ...
# 2604  069260   KOSPI     휴켐스               기타 화학제품 제조업
# 2607  189980  KOSDAQ  흥국에프엔비           비알코올음료 및 얼음 제조업
# 2608  000540   KOSPI    흥국화재                       보험업
# 2611  003280   KOSPI    흥아해운                    해상 운송업
# 2612  037440  KOSDAQ      희림  건축기술, 엔지니어링 및 관련 기술 서비스업
#
#                        Industry ListingDate SettleMonth  \
# 0                   반도체 웨이퍼 캐리어  2002-04-23         03월
# 1           렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                          지주사업  1999-08-11         12월
# 5                      위성통신 단말기  2016-03-04         12월
# 6                          지주회사  2014-05-19         12월
# ...                         ...         ...         ...
# 2604                화합물,화학제품 제조  2002-10-07         12월
# 2607  과일음료(에이드베이스, 스무디, 착즙쥬스 등)  2015-08-07         12월
# 2608                       손해보험  1974-12-05         12월
# 2611             외항화물운송업(케미컬탱커)  1976-06-29         12월
# 2612                  설계 및 감리용역  2000-02-03         12월
#
#                  Representative                       HomePage Region
# 0            박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1                           이현우         http://www.ajnet.co.kr  서울특별시
# 2             채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 5                           류장수          http://www.apsi.co.kr  서울특별시
# 6                           홍정국           http://www.bgf.co.kr  서울특별시
# ...                         ...                            ...    ...
# 2604                        신진용         http://www.huchems.com  서울특별시
# 2607                   박철범, 오길영        http://www.hyungkuk.com  서울특별시
# 2608                        권중원     http://www.insurance.co.kr  서울특별시
# 2611                        이환구         http://www.heung-a.com  서울특별시
# 2612  정영균, 이목운, 허철호, 염두성 (각자대표)          http://www.heerim.com  서울특별시
#
# [969 rows x 10 columns]

# %%
# 코스피 종목 가져오기
df[df['Market'] == 'KOSPI']
# Out:
#       Symbol Market     Name           Sector             Industry  \
# 1     095570  KOSPI   AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)
# 2     006840  KOSPI    AK홀딩스           기타 금융업                 지주사업
# 6     027410  KOSPI      BGF           기타 금융업                 지주회사
# 7     282330  KOSPI   BGF리테일           종합 소매업              체인화 편의점
# 8     138930  KOSPI  BNK금융지주           기타 금융업               금융지주회사
# ...      ...    ...      ...              ...                  ...
# 2604  069260  KOSPI      휴켐스      기타 화학제품 제조업          화합물,화학제품 제조
# 2608  000540  KOSPI     흥국화재              보험업                 손해보험
# 2609  000547  KOSPI  흥국화재2우B              NaN                  NaN
# 2610  000545  KOSPI    흥국화재우              NaN                  NaN
# 2611  003280  KOSPI     흥아해운           해상 운송업       외항화물운송업(케미컬탱커)
#
#      ListingDate SettleMonth     Representative  \
# 1     2015-08-21         12월                이현우
# 2     1999-08-11         12월  채형석, 이석주(각자 대표이사)
# 6     2014-05-19         12월                홍정국
# 7     2017-12-08         12월                이건준
# 8     2011-03-30         12월                김지완
# ...          ...         ...                ...
# 2604  2002-10-07         12월                신진용
# 2608  1974-12-05         12월                권중원
# 2609         NaN         NaN                NaN
# 2610         NaN         NaN                NaN
# 2611  1976-06-29         12월                이환구
#
#                            HomePage Region
# 1            http://www.ajnet.co.kr  서울특별시
# 2     http://www.aekyunggroup.co.kr  서울특별시
# 6              http://www.bgf.co.kr  서울특별시
# 7          http://www.bgfretail.com  서울특별시
# 8              http://www.bnkfg.com  부산광역시
# ...                             ...    ...
# 2604         http://www.huchems.com  서울특별시
# 2608     http://www.insurance.co.kr  서울특별시
# 2609                            NaN    NaN
# 2610                            NaN    NaN
# 2611         http://www.heung-a.com  서울특별시
#
# [1000 rows x 10 columns]

# %%
# 소재지가 서울특별시인 코스피 종목
# -> 각각의 조건을 괄호로 감싸준 후 비교 연산자를 수행해야 한다.
df[(df['Region'] == '서울특별시') & (df['Market'] == 'KOSPI')]
# Out:
#       Symbol Market    Name           Sector  \
# 1     095570  KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업
# 2     006840  KOSPI   AK홀딩스           기타 금융업
# 6     027410  KOSPI     BGF           기타 금융업
# 7     282330  KOSPI  BGF리테일           종합 소매업
# 9     001460  KOSPI     BYC         봉제의복 제조업
# ...      ...    ...     ...              ...
# 2598  079980  KOSPI     휴비스         화학섬유 제조업
# 2600  005010  KOSPI     휴스틸        1차 철강 제조업
# 2604  069260  KOSPI     휴켐스      기타 화학제품 제조업
# 2608  000540  KOSPI    흥국화재              보험업
# 2611  003280  KOSPI    흥아해운           해상 운송업
#
#                                            Industry ListingDate SettleMonth  \
# 1                               렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                                              지주사업  1999-08-11         12월
# 6                                              지주회사  2014-05-19         12월
# 7                                           체인화 편의점  2017-12-08         12월
# 9                  메리야스,란제리 제조,도매/건축공사/부동산 임대,분양,공급  1975-06-02         12월
# ...                                             ...         ...         ...
# 2598  합성섬유(폴리에스테르원사,원면),재생섬유,폴리에스텔 원사,원면,고상칩 제조,도소매  2012-02-23         12월
# 2600                          강관(배관용,구조용,유정용) 제조,도매  1973-06-29         12월
# 2604                                    화합물,화학제품 제조  2002-10-07         12월
# 2608                                           손해보험  1974-12-05         12월
# 2611                                 외항화물운송업(케미컬탱커)  1976-06-29         12월
#
#          Representative                       HomePage Region
# 1                   이현우         http://www.ajnet.co.kr  서울특별시
# 2     채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 6                   홍정국           http://www.bgf.co.kr  서울특별시
# 7                   이건준       http://www.bgfretail.com  서울특별시
# 9                 고 윤 성          http://home.byc.co.kr  서울특별시
# ...                 ...                            ...    ...
# 2598                신유동           http://www.huvis.com  서울특별시
# 2600                 박훈         http://www.husteel.com  서울특별시
# 2604                신진용         http://www.huchems.com  서울특별시
# 2608                권중원     http://www.insurance.co.kr  서울특별시
# 2611                이환구         http://www.heung-a.com  서울특별시
#
# [407 rows x 10 columns]

# %%
# 소재지가 서울특별시인 코스피 종목의 종목명과 종목코드
# df.loc[조건식, 열]
#  - 조건식에서 인덱스 반환
(df['Region'] == '서울특별시') & (df['Market'] == 'KOSPI')
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 2609    False
# 2610    False
# 2611     True
# 2612    False
# 2613    False
# Length: 2614, dtype: bool

# %%
df.loc[(df['Region'] == '서울특별시') & (df['Market'] == 'KOSPI'), ['Name', 'Symbol']]
# Out:
#         Name  Symbol
# 1     AJ네트웍스  095570
# 2      AK홀딩스  006840
# 6        BGF  027410
# 7     BGF리테일  282330
# 9        BYC  001460
# ...      ...     ...
# 2598     휴비스  079980
# 2600     휴스틸  005010
# 2604     휴켐스  069260
# 2608    흥국화재  000540
# 2611    흥아해운  003280
#
# [407 rows x 2 columns]

# %% [markdown]
# <br>
#
# ## 2.4 파생 변수 만들기

# %%
df['ListingDate'] # 상장일
# Out:
# 0       2002-04-23
# 1       2015-08-21
# 2       1999-08-11
# 3       2001-12-04
# 4       2017-04-07
#            ...
# 2609           NaN
# 2610           NaN
# 2611    1976-06-29
# 2612    2000-02-03
# 2613    2017-07-20
# Name: ListingDate, Length: 2614, dtype: object

# %% [markdown]
# <br>
#
# `Object` 타입(문자열)으로 되어 있지만 날짜 데이터이므로 `datetime`으로 바꿔줘야 한다.

# %%
df['ListingDate'] = pd.to_datetime(df['ListingDate'])
df['ListingDate']
# Out:
# 0      2002-04-23
# 1      2015-08-21
# 2      1999-08-11
# 3      2001-12-04
# 4      2017-04-07
#           ...
# 2609          NaT
# 2610          NaT
# 2611   1976-06-29
# 2612   2000-02-03
# 2613   2017-07-20
# Name: ListingDate, Length: 2614, dtype: datetime64[ns]

# %%
# 년도만 가져오기
df['ListingDate'].dt.year
# Out:
# 0       2002.0
# 1       2015.0
# 2       1999.0
# 3       2001.0
# 4       2017.0
#          ...
# 2609       NaN
# 2610       NaN
# 2611    1976.0
# 2612    2000.0
# 2613    2017.0
# Name: ListingDate, Length: 2614, dtype: float64

# %%
# 월만 가져오기
df['ListingDate'].dt.month
# Out:
# 0        4.0
# 1        8.0
# 2        8.0
# 3       12.0
# 4        4.0
#         ...
# 2609     NaN
# 2610     NaN
# 2611     6.0
# 2612     2.0
# 2613     7.0
# Name: ListingDate, Length: 2614, dtype: float64

# %%
# 일만 가져오기
df['ListingDate'].dt.day
# Out:
# 0       23.0
# 1       21.0
# 2       11.0
# 3        4.0
# 4        7.0
#         ...
# 2609     NaN
# 2610     NaN
# 2611    29.0
# 2612     3.0
# 2613    20.0
# Name: ListingDate, Length: 2614, dtype: float64

# %%
# ListingYear 파생 변수 생성
df['ListingYear'] = df['ListingDate'].dt.year
df
# Out:
#       Symbol  Market     Name                    Sector  \
# 0     060310  KOSDAQ       3S             특수 목적용 기계 제조업
# 1     095570   KOSPI   AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI    AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ   APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ    AP시스템             특수 목적용 기계 제조업
# ...      ...     ...      ...                       ...
# 2609  000547   KOSPI  흥국화재2우B                       NaN
# 2610  000545   KOSPI    흥국화재우                       NaN
# 2611  003280   KOSPI     흥아해운                    해상 운송업
# 2612  037440  KOSDAQ       희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 2613  238490  KOSDAQ       힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                               지주사업  1999-08-11         12월
# 3                        인터넷 트래픽 솔루션  2001-12-04         12월
# 4                        디스플레이 제조 장비  2017-04-07         12월
# ...                              ...         ...         ...
# 2609                             NaN         NaT         NaN
# 2610                             NaN         NaT         NaN
# 2611                  외항화물운송업(케미컬탱커)  1976-06-29         12월
# 2612                       설계 및 감리용역  2000-02-03         12월
# 2613  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20         12월
#
#                  Representative                       HomePage Region  \
# 0            박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1                           이현우         http://www.ajnet.co.kr  서울특별시
# 2             채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3                           정기로   http://www.apsholdings.co.kr    경기도
# 4                           김영주     http://www.apsystems.co.kr    경기도
# ...                         ...                            ...    ...
# 2609                        NaN                            NaN    NaN
# 2610                        NaN                            NaN    NaN
# 2611                        이환구         http://www.heung-a.com  서울특별시
# 2612  정영균, 이목운, 허철호, 염두성 (각자대표)          http://www.heerim.com  서울특별시
# 2613                        김주환          http://www.hims.co.kr  인천광역시
#
#       ListingYear
# 0          2002.0
# 1          2015.0
# 2          1999.0
# 3          2001.0
# 4          2017.0
# ...           ...
# 2609          NaN
# 2610          NaN
# 2611       1976.0
# 2612       2000.0
# 2613       2017.0
#
# [2614 rows x 11 columns]

# %%
df[['ListingDate', 'ListingYear']]
# Out:
#      ListingDate  ListingYear
# 0     2002-04-23       2002.0
# 1     2015-08-21       2015.0
# 2     1999-08-11       1999.0
# 3     2001-12-04       2001.0
# 4     2017-04-07       2017.0
# ...          ...          ...
# 2609         NaT          NaN
# 2610         NaT          NaN
# 2611  1976-06-29       1976.0
# 2612  2000-02-03       2000.0
# 2613  2017-07-20       2017.0
#
# [2614 rows x 2 columns]

# %%
df[['ListingDate', 'ListingYear']].describe()
# Out:
#        ListingYear
# count  2411.000000
# mean   2004.802986
# std      12.618063
# min    1956.000000
# 25%    1999.000000
# 50%    2007.000000
# 75%    2015.000000
# max    2020.000000

# %%
df[['ListingDate', 'ListingYear']].dtypes
# Out:
# ListingDate    datetime64[ns]
# ListingYear           float64
# dtype: object

# %% [markdown]
# <br>
#
# `ListingYear`는 결측치가 `NaN(float)`이기 때문에 타입이 float으로 지정된다.
