# %% [markdown]
# # 7. ETF 데이터 수집

# %% [markdown]
# ## 7.1 ETF란?
#
# > ETF(상장지수펀드)는 기초지수의 성과를 추적하는 것이 목표인 인덱스펀드로, 거래소에 상장되어 있어서 개별주식과 마찬가지로 기존의 주식계좌를 통해 거래를 할 수 있습니다. 그 구성종목과 수량 등 자산구성내역(PDF)이 투명하게 공개되어 있고, 장중에는 실시간으로 순자산가치(NAV)가 제공되어 거래에 참고하실 수 있습니다. ETF는 1좌를 거래할 수 있는 최소한의 금액만으로 분산투자 효과를 누릴 수 있어 효율적인 투자수단이며, 펀드보다 운용보수가 낮고 주식에 적용되는 거래세도 붙지 않습니다.
#
# - [출처 : 네이버 금융](https://finance.naver.com/sise/etf.nhn)

# %% [markdown]
# <br>
#
# ## 7.2 라이브러리 호출

# %%
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# <br>
#
# ## 7.3 크롬 브라우저의 네트워크 정보를 통한 데이터 수집

# %% [markdown]
# ### 7.3.1 수집할 URL

# %%
url = 'https://finance.naver.com/sise/etf.nhn'
url
# Out:
# 'https://finance.naver.com/sise/etf.nhn'

# %% [markdown]
# <br>
#
# ### 7.3.2 Pandas를 통한 요청

# %%
pd.read_html(url)
# Out:
# []

# %% [markdown]
# - 테이블 태그가 존재하지만 다음 url 주소의 response 값이 JSON 형태이다.

# %% [markdown]
# <br>
#
# ### 7.3.3 `requests`를 통한 HTTP 요청

# %%
url = 'https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc'
url
# Out:
# 'https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc'

# %%
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '{"resultCode":"success","result":{"etfItemList":[{"itemcode":"069500","etfTabCode":1,"itemname":"KODEX 200","nowVal":43130,"risefall":"2","changeVal":355,"changeRate":0.83,"nav":43214.0,"threeMonthEarnRate":39.9522,"quant":8521906,"amonut":366352,"marketSum":62625},{"itemcode":"102110","etfTabCode":1,"itemname":"TIGER 200","nowVal":42970,"risefall":"2","changeVal":360,"changeRate":0.84,"nav":43038.0,"threeMonthEarnRate":39.971,"quant":1650818,"amonut":70651,"marketSum":31347},{"itemcode":"252670","etfTabCode":3,"itemname":"KODEX 200선물인버스2X","nowVal":2055,"risefall":"5","changeVal":-35,"changeRate":-1.67,"nav":2051.0,"threeMonthEarnRate":-51.2821,"quant":642008913,"amonut":1329284,"marketSum":20227},{"itemcode":"122630","etfTabCode":3,"itemname":"KODEX 레버리지","nowVal":27825,"risefall":"2","changeVal":475,"changeRate":1.74,"nav":28022.0,"threeMonthEarnRate":92.0646,"quant":46157932,"amonut":1275107,"marketSum":19088},{"itemcode":"102780","etfTabCode":2,"itemname":"KODEX 삼성그룹","nowVal":10530,"risefall":"2","changeVal":70,"changeRate":0.67,"nav":10545.0,"threeMonthEarnRate":37.6315,"quant":612363,"amonut":6415,"marketSum":18522},{"itemcode":"278530","etfTabCode":1,"itemname":"KODEX 200TR","nowVal":13900,"risefall":"2","changeVal":125,"changeRate":0.91,"nav":13910.0,"threeMonthEarnRate":40.1322,"quant":358712,"amonut":4968,"marketSum":17577},{"itemcode":"153130","etfTabCode":6,"itemname":"KODEX 단기채권","nowVal":102690,"risefall":"2","changeVal":10,"changeRate":0.01,"nav":102685.0,"threeMonthEarnRate":0.1316,"quant":15291,"amonut":1570,"marketSum":17437},{"itemcode":"278540","etfTabCode":1,"itemname":"KODEX MSCI Korea TR","nowVal":13900,"risefall":"2","changeVal":85,"changeRate":0.62,"nav":13948.0,"threeMonthEarnRate":40.8975,"quant":276979,"amonut":3854,"marketSum":17278},{"itemcode":"310970","etfTabCode":1,"itemname":"TIGER MSCI Korea TR","nowVal":17525,"risefall":"2","changeVal":150,"changeRate":0.86,"nav":17518.0,"threeMonthEarnRate":41.3176,"quant":207514,"amonut":3620,"marketSum":16491},{"itemcode":"273130","etfTabCode":6,"itemname":"KODEX 종합채권(AA-이상)액티브","nowVal":109870,"risefall":"2","changeVal":15,"changeRate":0.01,"nav":109830.0,"threeMonthEarnRate":-0.4576,"quant":6949,"amonut":763,"marketSum":14997},{"itemcode":"148020","etfTabCode":1,"itemname":"KBSTAR 200","nowVal":43265,"risefall":"2","changeVal":400,"changeRate":0.93,"nav":43308.0,"threeMonthEarnRate":40.1412,"quant":654373,"amonut":28209,"marketSum":13153},{"itemcode":"114800","etfTabCode":3,"itemname":"KODEX 인버스","nowVal":3865,"risefall":"5","changeVal":-35,"changeRate":-0.9,"nav":3868.0,"threeMonthEarnRate":-29.6664,"quant":104465568,"amonut":405762,"marketSum":12252},{"itemcode":"233740","etfTabCode":1,"itemname":"KODEX 코스닥150 레버리지","nowVal":16205,"risefall":"2","changeVal":125,"changeRate":0.78,"nav":16339.0,"threeMonthEarnRate":47.5906,"quant":16490755,"amonut":263501,"marketSum":11651},{"itemcode":"305720","etfTabCode":2,"itemname":"KODEX 2차전지산업","nowVal":20175,"risefall":"2","changeVal":325,"changeRate":1.64,"nav":20250.0,"threeMonthEarnRate":74.4288,"quant":4103690,"amonut":82498,"marketSum":10390},{"itemcode":"152100","etfTabCode":1,"itemname":"ARIRANG 200","nowVal":43450,"risefall":"2","changeVal":360,"changeRate":0.84,"nav":43534.0,"threeMonthEarnRate":40.1574,"quant":130861,"amonut":5679,"marketSum":8581},{"itemcode":"292150","etfTabCode":2,"itemname":"TIGER TOP10","nowVal":15440,"risefall":"2","changeVal":185,"changeRate":1.21,"nav":15436.0,"threeMonthEarnRate":48.3228,"quant":878431,"amonut":13482,"marketSum":8376},{"itemcode":"139260","etfTabCode":2,"itemname":"TIGER 200 IT","nowVal":40980,"risefall":"2","changeVal":425,"changeRate":1.05,"nav":40976.0,"threeMonthEarnRate":58.9768,"quant":433317,"amonut":17640,"marketSum":8171},{"itemcode":"214980","etfTabCode":6,"itemname":"KODEX 단기채권PLUS","nowVal":102950,"risefall":"2","changeVal":10,"changeRate":0.01,"nav":102944.0,"threeMonthEarnRate":0.1605,"quant":4787,"amonut":492,"marketSum":8146},{"itemcode":"10 ...

# %% [markdown]
# <br>
#
# ### 7.3.4 JSON 타입으로 데이터 받기

# %%
etf_json = res.json()
etf_json
# Out:
# {'resultCode': 'success',
#  'result': {'etfItemList': [{'itemcode': '069500',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 200',
#     'nowVal': 43130,
#     'risefall': '2',
#     'changeVal': 355,
#     'changeRate': 0.83,
#     'nav': 43214.0,
#     'threeMonthEarnRate': 39.9522,
#     'quant': 8521906,
#     'amonut': 366352,
#     'marketSum': 62625},
#    {'itemcode': '102110',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 200',
#     'nowVal': 42970,
#     'risefall': '2',
#     'changeVal': 360,
#     'changeRate': 0.84,
#     'nav': 43038.0,
#     'threeMonthEarnRate': 39.971,
#     'quant': 1650818,
#     'amonut': 70651,
#     'marketSum': 31347},
#    {'itemcode': '252670',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 200선물인버스2X',
#     'nowVal': 2055,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -1.67,
#     'nav': 2051.0,
#     'threeMonthEarnRate': -51.2821,
#     'quant': 642008913,
#     'amonut': 1329284,
#     'marketSum': 20227},
#    {'itemcode': '122630',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 레버리지',
#     'nowVal': 27825,
#     'risefall': '2',
#     'changeVal': 475,
#     'changeRate': 1.74,
#     'nav': 28022.0,
#     'threeMonthEarnRate': 92.0646,
#     'quant': 46157932,
#     'amonut': 1275107,
#     'marketSum': 19088},
#    {'itemcode': '102780',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 삼성그룹',
#     'nowVal': 10530,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 0.67,
#     'nav': 10545.0,
#     'threeMonthEarnRate': 37.6315,
#     'quant': 612363,
#     'amonut': 6415,
#     'marketSum': 18522},
#    {'itemcode': '278530',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 200TR',
#     'nowVal': 13900,
#     'risefall': '2',
#     'changeVal': 125,
#     'changeRate': 0.91,
#     'nav': 13910.0,
#     'threeMonthEarnRate': 40.1322,
#     'quant': 358712,
#     'amonut': 4968,
#     'marketSum': 17577},
#    {'itemcode': '153130',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기채권',
#     'nowVal': 102690,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.01,
#     'nav': 102685.0,
#     'threeMonthEarnRate': 0.1316,
#     'quant': 15291,
#     'amonut': 1570,
#     'marketSum': 17437},
#    {'itemcode': '278540',
#     'etfTabCode': 1,
#     'itemname': 'KODEX MSCI Korea TR',
#     'nowVal': 13900,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 0.62,
#     'nav': 13948.0,
#     'threeMonthEarnRate': 40.8975,
#     'quant': 276979,
#     'amonut': 3854,
#     'marketSum': 17278},
#    {'itemcode': '310970',
#     'etfTabCode': 1,
#     'itemname': 'TIGER MSCI Korea TR',
#     'nowVal': 17525,
#     'risefall': '2',
#     'changeVal': 150,
#     'changeRate': 0.86,
#     'nav': 17518.0,
#     'threeMonthEarnRate': 41.3176,
#     'quant': 207514,
#     'amonut': 3620,
#     'marketSum': 16491},
#    {'itemcode': '273130',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 종합채권(AA-이상)액티브',
#     'nowVal': 109870,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.01,
#     'nav': 109830.0,
#     'threeMonthEarnRate': -0.4576,
#     'quant': 6949,
#     'amonut': 763,
#     'marketSum': 14997},
#    {'itemcode': '148020',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 200',
#     'nowVal': 43265,
#     'risefall': '2',
#     'changeVal': 400,
#     'changeRate': 0.93,
#     'nav': 43308.0,
#     'threeMonthEarnRate': 40.1412,
#     'quant': 654373,
#     'amonut': 28209,
#     'marketSum': 13153},
#    {'itemcode': '114800',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 인버스',
#     'nowVal': 3865,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.9,
#     'nav': 3868.0,
#     'threeMonthEarnRate': -29.6664,
#     'quant': 104465568,
#     'amonut': 405762,
#     'marketSum': 12252},
#    {'itemcode': '233740',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스닥150 레버리지',
#     'nowVal': 16205,
#     'risefall': '2',
#     'changeVal': 125,
#     'changeRate': 0.78,
#     'nav': 16339.0,
#     'threeMonthEarnRate': 47.5906,
#     'quant': 16490755,
#     'amonut': 263501,
#     'marketSum': 11651},
#    {'itemcode': '305720',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 2차전지산업',
#     'nowVal': 20175,
#     'risefall': '2',
#     'changeVal': 325,
#     'changeRate': 1.64,
#     'nav': 20250.0,
#     'threeMonthEarnRate': 74.4288,
#     'quant': 4103690,
#     'amonut': 82498,
#     'marketSum': 10390},
#    {'itemcode': '152100',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 200',
#     'nowVal': 43450,
#     'risefall': '2',
#     'changeVal': 360,
#     'changeRate': 0.84,
#     'nav': 43534.0,
#     'threeMonthEarnRate': 40.1574,
#     'quant': 130861,
#     'amonut': 5679,
#     'marketSum': 8581},
#    {'itemcode': '292150',
#     'etfTabCode': 2,
#     'itemname': 'TIGER TOP10',
#     'nowVal': 15440,
#     'risefall': '2',
#     'changeVal': 185,
#     'changeRate': 1.21,
#     'nav': 15436.0,
#     'threeMonthEarnRate': 48.3228,
#     'quant': 878431,
#     'amonut': 13482,
#     'marketSum': 8376},
#    {'itemcode': '139260',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 IT',
#     'nowVal': 40980,
#     'risefall': '2',
#     'changeVal': 425,
#     'changeRate': 1.05,
#     'nav': 40976.0,
#     'threeMonthEarnRate': 58.9768,
#     'quant': 433317,
#     'amonut': 17640,
#     'marketSum': 8171},
#    {'itemcode': '214980',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기채권PLUS',
#     'nowVal': 102950,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.01,
#     'nav': 102944.0,
#     'threeMonthEarnRate': 0.1605,
#     'quant': 4787,
#     'amonut': 492,
#     'marketSum': 8146},
#    {'itemcode': '105190',
#     'etfTabCode': 1,
#     'itemname': 'KINDEX 200',
#     'nowVal': 43425,
#     'risefall': '2',
#     'changeVal': 385,
#     'changeRate': 0.89,
#     'nav': 43485.0,
#     'threeMonthEarnRate': 40.1497,
#     'quant': 284592,
#     'amonut': 12286,
#     'marketSum': 7708},
#    {'itemcode': '364980',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX2차전지K-뉴딜',
#     'nowVal': 18515,
#     'risefall': '2',
#     'changeVal': 255,
#     'changeRate': 1.4,
#     'nav': 18514.0,
#     'threeMonthEarnRate': 87.0901,
#     'quant': 2648744,
#     'amonut': 48749,
#     'marketSum': 7600},
#    {'itemcode': '305540',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 2차전지테마',
#     'nowVal': 18315,
#     'risefall': '2',
#     'changeVal': 290,
#     'changeRate': 1.61,
#     'nav': 18387.0,
#     'threeMonthEarnRate': 69.1694,
#     'quant': 2867117,
#     'amonut': 52278,
#     'marketSum': 6969},
#    {'itemcode': '157450',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 단기통안채',
#     'nowVal': 100065,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 100062.0,
#     'threeMonthEarnRate': 0.115,
#     'quant': 5066,
#     'amonut': 506,
#     'marketSum': 6632},
#    {'itemcode': '069660',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 200',
#     'nowVal': 43290,
#     'risefall': '2',
#     'changeVal': 375,
#     'changeRate': 0.87,
#     'nav': 43357.0,
#     'threeMonthEarnRate': 40.1306,
#     'quant': 177623,
#     'amonut': 7657,
#     'marketSum': 6580},
#    {'itemcode': '293180',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200',
#     'nowVal': 43130,
#     'risefall': '2',
#     'changeVal': 345,
#     'changeRate': 0.81,
#     'nav': 43200.0,
#     'threeMonthEarnRate': 40.0124,
#     'quant': 55121,
#     'amonut': 2370,
#     'marketSum': 6426},
#    {'itemcode': '133690',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국나스닥100',
#     'nowVal': 67650,
#     'risefall': '2',
#     'changeVal': 1040,
#     'changeRate': 1.56,
#     'nav': None,
#     'threeMonthEarnRate': 18.4493,
#     'quant': 118273,
#     'amonut': 7975,
#     'marketSum': 6359},
#    {'itemcode': '294400',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 200TR',
#     'nowVal': 50440,
#     'risefall': '2',
#     'changeVal': 415,
#     'changeRate': 0.83,
#     'nav': 50525.0,
#     'threeMonthEarnRate': 40.2242,
#     'quant': 18814,
#     'amonut': 946,
#     'marketSum': 4767},
#    {'itemcode': '295040',
#     'etfTabCode': 1,
#     'itemname': 'SMART 200TR',
#     'nowVal': 14435,
#     'risefall': '2',
#     'changeVal': 110,
#     'changeRate': 0.77,
#     'nav': 14467.0,
#     'threeMonthEarnRate': 40.3723,
#     'quant': 26535,
#     'amonut': 381,
#     'marketSum': 4612},
#    {'itemcode': '332940',
#     'etfTabCode': 1,
#     'itemname': 'HANARO MSCI Korea TR',
#     'nowVal': 17500,
#     'risefall': '2',
#     'changeVal': 205,
#     'changeRate': 1.19,
#     'nav': 17505.0,
#     'threeMonthEarnRate': 40.4955,
#     'quant': 55,
#     'amonut': 0,
#     'marketSum': 4463},
#    {'itemcode': '357870',
#     'etfTabCode': 7,
#     'itemname': 'TIGER CD금리투자KIS(합성)',
#     'nowVal': 50195,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 50197.0,
#     'threeMonthEarnRate': 0.1496,
#     'quant': 13,
#     'amonut': 0,
#     'marketSum': 4397},
#    {'itemcode': '371460',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나전기차SOLACTIVE',
#     'nowVal': 13660,
#     'risefall': '2',
#     'changeVal': 210,
#     'changeRate': 1.56,
#     'nav': None,
#     'threeMonthEarnRate': None,
#     'quant': 2183188,
#     'amonut': 29844,
#     'marketSum': 4393},
#    {'itemcode': '364960',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX BBIG K-뉴딜',
#     'nowVal': 13885,
#     'risefall': '2',
#     'changeVal': 105,
#     'changeRate': 0.76,
#     'nav': 13931.0,
#     'threeMonthEarnRate': 42.4289,
#     'quant': 1452332,
#     'amonut': 20077,
#     'marketSum': 4277},
#    {'itemcode': '251340',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 코스닥150선물인버스',
#     'nowVal': 4440,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.34,
#     'nav': 4453.0,
#     'threeMonthEarnRate': -20.5883,
#     'quant': 55943952,
#     'amonut': 250588,
#     'marketSum': 4245},
#    {'itemcode': '261220',
#     'etfTabCode': 5,
#     'itemname': 'KODEX WTI원유선물(H)',
#     'nowVal': 8215,
#     'risefall': '2',
#     'changeVal': 105,
#     'changeRate': 1.29,
#     'nav': None,
#     'threeMonthEarnRate': 52.0149,
#     'quant': 1846418,
#     'amonut': 15192,
#     'marketSum': 4025},
#    {'itemcode': '315930',
#     'etfTabCode': 2,
#     'itemname': 'KODEX Top5PlusTR',
#     'nowVal': 19445,
#     'risefall': '2',
#     'changeVal': 175,
#     'changeRate': 0.91,
#     'nav': 19430.0,
#     'threeMonthEarnRate': 39.2844,
#     'quant': 9133,
#     'amonut': 176,
#     'marketSum': 4006},
#    {'itemcode': '226490',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스피',
#     'nowVal': 31925,
#     'risefall': '2',
#     'changeVal': 405,
#     'changeRate': 1.28,
#     'nav': 31927.0,
#     'threeMonthEarnRate': 36.6276,
#     'quant': 171220,
#     'amonut': 5436,
#     'marketSum': 3863},
#    {'itemcode': '229200',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스닥 150',
#     'nowVal': 15090,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 0.5,
#     'nav': 15192.0,
#     'threeMonthEarnRate': 22.3716,
#     'quant': 2836019,
#     'amonut': 42442,
#     'marketSum': 3840},
#    {'itemcode': '314250',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국FANG플러스(H)',
#     'nowVal': 27280,
#     'risefall': '2',
#     'changeVal': 480,
#     'changeRate': 1.79,
#     'nav': None,
#     'threeMonthEarnRate': 25.0583,
#     'quant': 340070,
#     'amonut': 9245,
#     'marketSum': 3819},
#    {'itemcode': '251350',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 선진국MSCI World',
#     'nowVal': 16945,
#     'risefall': '2',
#     'changeVal': 150,
#     'changeRate': 0.89,
#     'nav': None,
#     'threeMonthEarnRate': 16.6724,
#     'quant': 18646,
#     'amonut': 315,
#     'marketSum': 3796},
#    {'itemcode': '091180',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 자동차',
#     'nowVal': 26230,
#     'risefall': '2',
#     'changeVal': 1220,
#     'changeRate': 4.88,
#     'nav': 26246.0,
#     'threeMonthEarnRate': 58.8945,
#     'quant': 2994541,
#     'amonut': 78317,
#     'marketSum': 3685},
#    {'itemcode': '192090',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나CSI300',
#     'nowVal': 12470,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.08,
#     'nav': None,
#     'threeMonthEarnRate': 16.8307,
#     'quant': 579804,
#     'amonut': 7238,
#     'marketSum': 3566},
#    {'itemcode': '332500',
#     'etfTabCode': 1,
#     'itemname': 'KINDEX 200TR',
#     'nowVal': 25880,
#     'risefall': '2',
#     'changeVal': 230,
#     'changeRate': 0.9,
#     'nav': 25902.0,
#     'threeMonthEarnRate': 40.2022,
#     'quant': 25954,
#     'amonut': 667,
#     'marketSum': 3416},
#    {'itemcode': '232080',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 코스닥150',
#     'nowVal': 15160,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.43,
#     'nav': 15270.0,
#     'threeMonthEarnRate': 22.1772,
#     'quant': 121785,
#     'amonut': 1833,
#     'marketSum': 2532},
#    {'itemcode': '132030',
#     'etfTabCode': 5,
#     'itemname': 'KODEX 골드선물(H)',
#     'nowVal': 12565,
#     'risefall': '5',
#     'changeVal': -125,
#     'changeRate': -0.99,
#     'nav': None,
#     'threeMonthEarnRate': -2.1966,
#     'quant': 218169,
#     'amonut': 2743,
#     'marketSum': 2463},
#    {'itemcode': '275980',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌4차산업혁신기술(합성 H)',
#     'nowVal': 18030,
#     'risefall': '2',
#     'changeVal': 205,
#     'changeRate': 1.15,
#     'nav': None,
#     'threeMonthEarnRate': 24.6939,
#     'quant': 146328,
#     'amonut': 2627,
#     'marketSum': 2452},
#    {'itemcode': '148070',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 국고채10년',
#     'nowVal': 122485,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.04,
#     'nav': 122467.0,
#     'threeMonthEarnRate': -0.7252,
#     'quant': 6511,
#     'amonut': 797,
#     'marketSum': 2450},
#    {'itemcode': '290130',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR ESG사회책임투자',
#     'nowVal': 14340,
#     'risefall': '2',
#     'changeVal': 175,
#     'changeRate': 1.24,
#     'nav': 14336.0,
#     'threeMonthEarnRate': 44.3934,
#     'quant': 691445,
#     'amonut': 9881,
#     'marketSum': 2330},
#    {'itemcode': '168580',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 중국본토CSI300',
#     'nowVal': 33380,
#     'risefall': '2',
#     'changeVal': 185,
#     'changeRate': 0.56,
#     'nav': None,
#     'threeMonthEarnRate': 17.7545,
#     'quant': 13784,
#     'amonut': 459,
#     'marketSum': 2170},
#    {'itemcode': '091170',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 은행',
#     'nowVal': 6110,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.41,
#     'nav': 6145.0,
#     'threeMonthEarnRate': 6.8815,
#     'quant': 506740,
#     'amonut': 3114,
#     'marketSum': 2145},
#    {'itemcode': '278240',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스닥150선물레버리지',
#     'nowVal': 16290,
#     'risefall': '2',
#     'changeVal': 80,
#     'changeRate': 0.49,
#     'nav': 16279.0,
#     'threeMonthEarnRate': 48.9889,
#     'quant': 138450,
#     'amonut': 2230,
#     'marketSum': 2110},
#    {'itemcode': '306540',
#     'etfTabCode': 6,
#     'itemname': 'HANARO 단기통안채',
#     'nowVal': 102920,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 102931.0,
#     'threeMonthEarnRate': 0.1118,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 2047},
#    {'itemcode': '245710',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 베트남VN30(합성)',
#     'nowVal': 15590,
#     'risefall': '2',
#     'changeVal': 540,
#     'changeRate': 3.59,
#     'nav': None,
#     'threeMonthEarnRate': 17.3489,
#     'quant': 309226,
#     'amonut': 4773,
#     'marketSum': 2042},
#    {'itemcode': '367770',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn수소경제테마',
#     'nowVal': 13840,
#     'risefall': '2',
#     'changeVal': 270,
#     'changeRate': 1.99,
#     'nav': 13838.0,
#     'threeMonthEarnRate': 36.3134,
#     'quant': 1423245,
#     'amonut': 19644,
#     'marketSum': 1861},
#    {'itemcode': '328370',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 코스피TR',
#     'nowVal': 15680,
#     'risefall': '2',
#     'changeVal': 240,
#     'changeRate': 1.55,
#     'nav': 15679.0,
#     'threeMonthEarnRate': 37.0008,
#     'quant': 15674,
#     'amonut': 243,
#     'marketSum': 1850},
#    {'itemcode': '302450',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스피',
#     'nowVal': 32020,
#     'risefall': '2',
#     'changeVal': 340,
#     'changeRate': 1.07,
#     'nav': 32013.0,
#     'threeMonthEarnRate': 37.5895,
#     'quant': 82,
#     'amonut': 2,
#     'marketSum': 1841},
#    {'itemcode': '270810',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스닥150',
#     'nowVal': 14845,
#     'risefall': '2',
#     'changeVal': 100,
#     'changeRate': 0.68,
#     'nav': 14951.0,
#     'threeMonthEarnRate': 21.2582,
#     'quant': 14403,
#     'amonut': 211,
#     'marketSum': 1820},
#    {'itemcode': '332930',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200TR',
#     'nowVal': 50535,
#     'risefall': '2',
#     'changeVal': 570,
#     'changeRate': 1.14,
#     'nav': 50579.0,
#     'threeMonthEarnRate': 39.8796,
#     'quant': 3837,
#     'amonut': 193,
#     'marketSum': 1693},
#    {'itemcode': '325020',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 배당가치',
#     'nowVal': 12825,
#     'risefall': '2',
#     'changeVal': 150,
#     'changeRate': 1.18,
#     'nav': 12815.0,
#     'threeMonthEarnRate': 28.2245,
#     'quant': 142218,
#     'amonut': 1810,
#     'marketSum': 1693},
#    {'itemcode': '150460',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 중국소비테마',
#     'nowVal': 7915,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.13,
#     'nav': 7915.0,
#     'threeMonthEarnRate': 20.8715,
#     'quant': 73948,
#     'amonut': 582,
#     'marketSum': 1691},
#    {'itemcode': '204480',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나CSI300레버리지(합성)',
#     'nowVal': 36810,
#     'risefall': '2',
#     'changeVal': 210,
#     'changeRate': 0.57,
#     'nav': None,
#     'threeMonthEarnRate': 43.9244,
#     'quant': 420860,
#     'amonut': 15479,
#     'marketSum': 1620},
#    {'itemcode': '272580',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 단기채권액티브',
#     'nowVal': 50040,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.01,
#     'nav': 50036.0,
#     'threeMonthEarnRate': 0.1,
#     'quant': 2799,
#     'amonut': 140,
#     'marketSum': 1605},
#    {'itemcode': '161510',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 고배당주',
#     'nowVal': 10560,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.33,
#     'nav': 10607.0,
#     'threeMonthEarnRate': 11.1991,
#     'quant': 46658,
#     'amonut': 492,
#     'marketSum': 1603},
#    {'itemcode': '091160',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 반도체',
#     'nowVal': 36065,
#     'risefall': '2',
#     'changeVal': 95,
#     'changeRate': 0.26,
#     'nav': 36203.0,
#     'threeMonthEarnRate': 43.9087,
#     'quant': 292684,
#     'amonut': 10521,
#     'marketSum': 1497},
#    {'itemcode': '196230',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 단기통안채',
#     'nowVal': 104265,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.01,
#     'nav': 104264.0,
#     'threeMonthEarnRate': 0.1537,
#     'quant': 1282477,
#     'amonut': 133711,
#     'marketSum': 1487},
#    {'itemcode': '143860',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 헬스케어',
#     'nowVal': 49890,
#     'risefall': '5',
#     'changeVal': -445,
#     'changeRate': -0.88,
#     'nav': 50147.0,
#     'threeMonthEarnRate': 20.6206,
#     'quant': 67025,
#     'amonut': 3325,
#     'marketSum': 1407},
#    {'itemcode': '143850',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500선물(H)',
#     'nowVal': 44725,
#     'risefall': '2',
#     'changeVal': 595,
#     'changeRate': 1.35,
#     'nav': None,
#     'threeMonthEarnRate': 15.8723,
#     'quant': 55436,
#     'amonut': 2476,
#     'marketSum': 1398},
#    {'itemcode': '144600',
#     'etfTabCode': 5,
#     'itemname': 'KODEX 은선물(H)',
#     'nowVal': 5570,
#     'risefall': '5',
#     'changeVal': -415,
#     'changeRate': -6.93,
#     'nav': None,
#     'threeMonthEarnRate': 19.1044,
#     'quant': 3489736,
#     'amonut': 19557,
#     'marketSum': 1387},
#    {'itemcode': '190620',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 단기통안채',
#     'nowVal': 100155,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 100158.0,
#     'threeMonthEarnRate': 0.1239,
#     'quant': 591,
#     'amonut': 59,
#     'marketSum': 1382},
#    {'itemcode': '267770',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 200선물레버리지',
#     'nowVal': 20835,
#     'risefall': '2',
#     'changeVal': 335,
#     'changeRate': 1.63,
#     'nav': 20890.0,
#     'threeMonthEarnRate': 91.4098,
#     'quant': 2167499,
#     'amonut': 44714,
#     'marketSum': 1354},
#    {'itemcode': '360750',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500',
#     'nowVal': 10785,
#     'risefall': '2',
#     'changeVal': 125,
#     'changeRate': 1.17,
#     'nav': None,
#     'threeMonthEarnRate': 14.0961,
#     'quant': 196555,
#     'amonut': 2117,
#     'marketSum': 1337},
#    {'itemcode': '139280',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 경기방어',
#     'nowVal': 12900,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.42,
#     'nav': 12902.0,
#     'threeMonthEarnRate': 19.7873,
#     'quant': 35099,
#     'amonut': 449,
#     'marketSum': 1269},
#    {'itemcode': '325010',
#     'etfTabCode': 2,
#     'itemname': 'KODEX Fn성장',
#     'nowVal': 19195,
#     'risefall': '2',
#     'changeVal': 145,
#     'changeRate': 0.76,
#     'nav': 19170.0,
#     'threeMonthEarnRate': 41.0066,
#     'quant': 4240,
#     'amonut': 80,
#     'marketSum': 1267},
#    {'itemcode': '138540',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 현대차그룹+펀더멘털',
#     'nowVal': 28115,
#     'risefall': '2',
#     'changeVal': 1110,
#     'changeRate': 4.11,
#     'nav': 28138.0,
#     'threeMonthEarnRate': 48.8699,
#     'quant': 328104,
#     'amonut': 9256,
#     'marketSum': 1243},
#    {'itemcode': '360200',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 미국S&P500',
#     'nowVal': 10860,
#     'risefall': '2',
#     'changeVal': 125,
#     'changeRate': 1.16,
#     'nav': None,
#     'threeMonthEarnRate': 14.0322,
#     'quant': 116912,
#     'amonut': 1267,
#     'marketSum': 1205},
#    {'itemcode': '367380',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 미국나스닥100',
#     'nowVal': 11620,
#     'risefall': '2',
#     'changeVal': 180,
#     'changeRate': 1.57,
#     'nav': None,
#     'threeMonthEarnRate': 18.2795,
#     'quant': 131991,
#     'amonut': 1527,
#     'marketSum': 1197},
#    {'itemcode': '273140',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기변동금리부채권액티브',
#     'nowVal': 102415,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.01,
#     'nav': 102412.0,
#     'threeMonthEarnRate': 0.1515,
#     'quant': 960,
#     'amonut': 98,
#     'marketSum': 1169},
#    {'itemcode': '233160',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 코스닥150 레버리지',
#     'nowVal': 17175,
#     'risefall': '2',
#     'changeVal': 105,
#     'changeRate': 0.62,
#     'nav': 17307.0,
#     'threeMonthEarnRate': 47.6005,
#     'quant': 256576,
#     'amonut': 4350,
#     'marketSum': 1142},
#    {'itemcode': '176950',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국채선물10년인버스',
#     'nowVal': 46335,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.05,
#     'nav': 46350.0,
#     'threeMonthEarnRate': 1.1356,
#     'quant': 222,
#     'amonut': 10,
#     'marketSum': 1134},
#    {'itemcode': '252710',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 200선물인버스2X',
#     'nowVal': 2125,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -1.62,
#     'nav': 2123.0,
#     'threeMonthEarnRate': -51.2416,
#     'quant': 5765820,
#     'amonut': 12333,
#     'marketSum': 1120},
#    {'itemcode': '130680',
#     'etfTabCode': 5,
#     'itemname': 'TIGER 원유선물Enhanced(H)',
#     'nowVal': 2470,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 1.23,
#     'nav': None,
#     'threeMonthEarnRate': 39.828,
#     'quant': 884160,
#     'amonut': 2189,
#     'marketSum': 1091},
#    {'itemcode': '219480',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국S&P500선물(H)',
#     'nowVal': 18380,
#     'risefall': '2',
#     'changeVal': 235,
#     'changeRate': 1.3,
#     'nav': None,
#     'threeMonthEarnRate': 15.7575,
#     'quant': 59547,
#     'amonut': 1093,
#     'marketSum': 1084},
#    {'itemcode': '108450',
#     'etfTabCode': 2,
#     'itemname': 'KINDEX 삼성그룹섹터가중',
#     'nowVal': 16910,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.03,
#     'nav': 16984.0,
#     'threeMonthEarnRate': 39.6203,
#     'quant': 4275,
#     'amonut': 71,
#     'marketSum': 1082},
#    {'itemcode': '156080',
#     'etfTabCode': 1,
#     'itemname': 'KODEX MSCI Korea',
#     'nowVal': 20585,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.24,
#     'nav': 20715.0,
#     'threeMonthEarnRate': 41.0855,
#     'quant': 195,
#     'amonut': 4,
#     'marketSum': 1029},
#    {'itemcode': '282000',
#     'etfTabCode': 3,
#     'itemname': 'KBSTAR 국고채3년선물인버스',
#     'nowVal': 99425,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.02,
#     'nav': 99422.0,
#     'threeMonthEarnRate': -0.0252,
#     'quant': 13,
#     'amonut': 1,
#     'marketSum': 1026},
#    {'itemcode': '368190',
#     'etfTabCode': 2,
#     'itemname': 'HANARO Fn K-뉴딜디지털플러스',
#     'nowVal': 13750,
#     'risefall': '2',
#     'changeVal': 125,
#     'changeRate': 0.92,
#     'nav': 13801.0,
#     'threeMonthEarnRate': None,
#     'quant': 472127,
#     'amonut': 6458,
#     'marketSum': 1024},
#    {'itemcode': '371160',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나항셍테크',
#     'nowVal': 12585,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 0.56,
#     'nav': None,
#     'threeMonthEarnRate': None,
#     'quant': 565970,
#     'amonut': 7104,
#     'marketSum': 1007},
#    {'itemcode': '367760',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn5G테크',
#     'nowVal': 12315,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 0.61,
#     'nav': 12331.0,
#     'threeMonthEarnRate': 24.5167,
#     'quant': 127617,
#     'amonut': 1568,
#     'marketSum': 985},
#    {'itemcode': '091230',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 반도체',
#     'nowVal': 37090,
#     'risefall': '2',
#     'changeVal': 220,
#     'changeRate': 0.6,
#     'nav': 37077.0,
#     'threeMonthEarnRate': 43.2679,
#     'quant': 71687,
#     'amonut': 2638,
#     'marketSum': 979},
#    {'itemcode': '283580',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 중국본토CSI300',
#     'nowVal': 15015,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.27,
#     'nav': None,
#     'threeMonthEarnRate': 17.2211,
#     'quant': 42542,
#     'amonut': 638,
#     'marketSum': 961},
#    {'itemcode': '315960',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 대형고배당10TR',
#     'nowVal': 16730,
#     'risefall': '2',
#     'changeVal': 195,
#     'changeRate': 1.18,
#     'nav': 16716.0,
#     'threeMonthEarnRate': 39.5358,
#     'quant': 4489,
#     'amonut': 75,
#     'marketSum': 954},
#    {'itemcode': '225040',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500레버리지(합성 H)',
#     'nowVal': 25580,
#     'risefall': '2',
#     'changeVal': 705,
#     'changeRate': 2.83,
#     'nav': None,
#     'threeMonthEarnRate': 32.8792,
#     'quant': 20028,
#     'amonut': 510,
#     'marketSum': 946},
#    {'itemcode': '114260',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국고채3년',
#     'nowVal': 58140,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.03,
#     'nav': 58161.0,
#     'threeMonthEarnRate': 0.1464,
#     'quant': 14536,
#     'amonut': 845,
#     'marketSum': 942},
#    {'itemcode': '302190',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 중장기국채',
#     'nowVal': 52795,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.06,
#     'nav': 52777.0,
#     'threeMonthEarnRate': -0.3852,
#     'quant': 3596,
#     'amonut': 189,
#     'marketSum': 898},
#    {'itemcode': '292190',
#     'etfTabCode': 1,
#     'itemname': 'KODEX KRX300',
#     'nowVal': 19940,
#     'risefall': '2',
#     'changeVal': 185,
#     'changeRate': 0.94,
#     'nav': 19949.0,
#     'threeMonthEarnRate': 38.2435,
#     'quant': 70633,
#     'amonut': 1402,
#     'marketSum': 857},
#    {'itemcode': '195930',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 유로스탁스50(합성 H)',
#     'nowVal': 12120,
#     'risefall': '2',
#     'changeVal': 245,
#     'changeRate': 2.06,
#     'nav': None,
#     'threeMonthEarnRate': 19.2269,
#     'quant': 17732,
#     'amonut': 214,
#     'marketSum': 848},
#    {'itemcode': '364970',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX바이오K-뉴딜',
#     'nowVal': 12160,
#     'risefall': '5',
#     'changeVal': -105,
#     'changeRate': -0.86,
#     'nav': 12165.0,
#     'threeMonthEarnRate': 22.1005,
#     'quant': 312086,
#     'amonut': 3777,
#     'marketSum': 845},
#    {'itemcode': '272560',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 단기국공채액티브',
#     'nowVal': 101795,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.01,
#     'nav': 101791.0,
#     'threeMonthEarnRate': 0.2462,
#     'quant': 1152,
#     'amonut': 117,
#     'marketSum': 799},
#    {'itemcode': '245360',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나HSCEI',
#     'nowVal': 13495,
#     'risefall': '5',
#     'changeVal': -100,
#     'changeRate': -0.74,
#     'nav': None,
#     'threeMonthEarnRate': 14.7257,
#     'quant': 22548,
#     'amonut': 303,
#     'marketSum': 783},
#    {'itemcode': '102970',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 증권',
#     'nowVal': 7915,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.76,
#     'nav': 7911.0,
#     'threeMonthEarnRate': 24.8807,
#     'quant': 140449,
#     'amonut': 1110,
#     'marketSum': 712},
#    {'itemcode': '195980',
#     'etfTabCode': 4,
#     'itemname': 'ARIRANG 신흥국MSCI(합성 H)',
#     'nowVal': 13410,
#     'risefall': '2',
#     'changeVal': 95,
#     'changeRate': 0.71,
#     'nav': None,
#     'threeMonthEarnRate': 23.9181,
#     'quant': 45635,
#     'amonut': 609,
#     'marketSum': 705},
#    {'itemcode': '292500',
#     'etfTabCode': 1,
#     'itemname': 'SMART KRX300',
#     'nowVal': 19880,
#     'risefall': '2',
#     'changeVal': 125,
#     'changeRate': 0.63,
#     'nav': 19922.0,
#     'threeMonthEarnRate': 38.8752,
#     'quant': 9503,
#     'amonut': 188,
#     'marketSum': 696},
#    {'itemcode': '261240',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 미국달러선물',
#     'nowVal': 9880,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.1,
#     'nav': 9882.0,
#     'threeMonthEarnRate': -1.3959,
#     'quant': 169488,
#     'amonut': 1673,
#     'marketSum': 684},
#    {'itemcode': '372330',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나항셍테크',
#     'nowVal': 12610,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.44,
#     'nav': None,
#     'threeMonthEarnRate': None,
#     'quant': 610555,
#     'amonut': 7688,
#     'marketSum': 668},
#    {'itemcode': '256750',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 심천ChiNext(합성)',
#     'nowVal': 14135,
#     'risefall': '2',
#     'changeVal': 155,
#     'changeRate': 1.11,
#     'nav': None,
#     'threeMonthEarnRate': 22.0427,
#     'quant': 96199,
#     'amonut': 1362,
#     'marketSum': 664},
#    {'itemcode': '182480',
#     'etfTabCode': 7,
#     'itemname': 'TIGER 미국MSCI리츠(합성 H)',
#     'nowVal': 12435,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.53,
#     'nav': None,
#     'threeMonthEarnRate': 16.1066,
#     'quant': 15436,
#     'amonut': 192,
#     'marketSum': 659},
#    {'itemcode': '371470',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나바이오테크SOLACTIVE',
#     'nowVal': 13280,
#     'risefall': '2',
#     'changeVal': 185,
#     'changeRate': 1.41,
#     'nav': None,
#     'threeMonthEarnRate': None,
#     'quant': 263913,
#     'amonut': 3477,
#     'marketSum': 659},
#    {'itemcode': '310960',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 200TR',
#     'nowVal': 22615,
#     'risefall': '2',
#     'changeVal': 185,
#     'changeRate': 0.82,
#     'nav': 22667.0,
#     'threeMonthEarnRate': 40.0561,
#     'quant': 1505,
#     'amonut': 33,
#     'marketSum': 656},
#    {'itemcode': '277630',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 코스피',
#     'nowVal': 31770,
#     'risefall': '2',
#     'changeVal': 325,
#     'changeRate': 1.03,
#     'nav': 31888.0,
#     'threeMonthEarnRate': 36.9436,
#     'quant': 4759,
#     'amonut': 150,
#     'marketSum': 651},
#    {'itemcode': '114820',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 국채3년',
#     'nowVal': 111300,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.05,
#     'nav': 111305.0,
#     'threeMonthEarnRate': 0.2297,
#     'quant': 499,
#     'amonut': 55,
#     'marketSum': 634},
#    {'itemcode': '336160',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 금융채액티브',
#     'nowVal': 103450,
#     'risefall': '2',
#     'changeVal': 80,
#     'changeRate': 0.08,
#     'nav': 103420.0,
#     'threeMonthEarnRate': 0.5789,
#     'quant': 11,
#     'amonut': 1,
#     'marketSum': 631},
#    {'itemcode': '363580',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 200IT TR',
#     'nowVal': 15300,
#     'risefall': '2',
#     'changeVal': 125,
#     'changeRate': 0.82,
#     'nav': 15341.0,
#     'threeMonthEarnRate': 58.8173,
#     'quant': 6502,
#     'amonut': 99,
#     'marketSum': 627},
#    {'itemcode': '157490',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 소프트웨어',
#     'nowVal': 16950,
#     'risefall': '2',
#     'changeVal': 445,
#     'changeRate': 2.7,
#     'nav': 16975.0,
#     'threeMonthEarnRate': 25.561,
#     'quant': 227965,
#     'amonut': 3832,
#     'marketSum': 627},
#    {'itemcode': '326240',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR IT플러스',
#     'nowVal': 21925,
#     'risefall': '2',
#     'changeVal': 230,
#     'changeRate': 1.06,
#     'nav': 21995.0,
#     'threeMonthEarnRate': 42.2622,
#     'quant': 182470,
#     'amonut': 3983,
#     'marketSum': 627},
#    {'itemcode': '219390',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국S&P원유생산기업(합성 H)',
#     'nowVal': 3005,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': None,
#     'threeMonthEarnRate': 59.8404,
#     'quant': 223531,
#     'amonut': 670,
#     'marketSum': 624},
#    {'itemcode': '329200',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 부동산인프라고배당',
#     'nowVal': 4980,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.3,
#     'nav': 5006.0,
#     'threeMonthEarnRate': 6.8661,
#     'quant': 77959,
#     'amonut': 387,
#     'marketSum': 618},
#    {'itemcode': '289260',
#     'etfTabCode': 2,
#     'itemname': 'TIGER MSCI KOREA ESG리더스',
#     'nowVal': 12390,
#     'risefall': '2',
#     'changeVal': 150,
#     'changeRate': 1.23,
#     'nav': 12402.0,
#     'threeMonthEarnRate': 41.5028,
#     'quant': 12131,
#     'amonut': 149,
#     'marketSum': 610},
#    {'itemcode': '243880',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200IT레버리지',
#     'nowVal': 75190,
#     'risefall': '2',
#     'changeVal': 990,
#     'changeRate': 1.33,
#     'nav': 75796.0,
#     'threeMonthEarnRate': 147.3333,
#     'quant': 28875,
#     'amonut': 2160,
#     'marketSum': 602},
#    {'itemcode': '298770',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 한국대만IT프리미어',
#     'nowVal': 20050,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.33,
#     'nav': None,
#     'threeMonthEarnRate': 42.2419,
#     'quant': 224856,
#     'amonut': 4510,
#     'marketSum': 602},
#    {'itemcode': '266360',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 미디어&엔터테인먼트',
#     'nowVal': 22170,
#     'risefall': '2',
#     'changeVal': 480,
#     'changeRate': 2.21,
#     'nav': 22169.0,
#     'threeMonthEarnRate': 24.7268,
#     'quant': 51358,
#     'amonut': 1126,
#     'marketSum': 599},
#    {'itemcode': '136340',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 중기우량회사채',
#     'nowVal': 105520,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.02,
#     'nav': 105492.0,
#     'threeMonthEarnRate': 0.9501,
#     'quant': 1381,
#     'amonut': 145,
#     'marketSum': 591},
#    {'itemcode': '266370',
#     'etfTabCode': 2,
#     'itemname': 'KODEX IT',
#     'nowVal': 22290,
#     'risefall': '2',
#     'changeVal': 270,
#     'changeRate': 1.23,
#     'nav': 22284.0,
#     'threeMonthEarnRate': 50.5126,
#     'quant': 33465,
#     'amonut': 742,
#     'marketSum': 580},
#    {'itemcode': '304780',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200선물레버리지',
#     'nowVal': 30260,
#     'risefall': '2',
#     'changeVal': 475,
#     'changeRate': 1.59,
#     'nav': 30346.0,
#     'threeMonthEarnRate': 91.9755,
#     'quant': 3493,
#     'amonut': 103,
#     'marketSum': 575},
#    {'itemcode': '123310',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 인버스',
#     'nowVal': 4255,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.93,
#     'nav': 4263.0,
#     'threeMonthEarnRate': -29.5902,
#     'quant': 777440,
#     'amonut': 3322,
#     'marketSum': 570},
#    {'itemcode': '337140',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 코스피대형주',
#     'nowVal': 15185,
#     'risefall': '2',
#     'changeVal': 90,
#     'changeRate': 0.6,
#     'nav': 15247.0,
#     'threeMonthEarnRate': 39.5101,
#     'quant': 1472,
#     'amonut': 22,
#     'marketSum': 547},
#    {'itemcode': '174360',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 중국본토대형주CSI100',
#     'nowVal': 23580,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 0.3,
#     'nav': None,
#     'threeMonthEarnRate': 18.6175,
#     'quant': 62430,
#     'amonut': 1463,
#     'marketSum': 542},
#    {'itemcode': '137610',
#     'etfTabCode': 5,
#     'itemname': 'TIGER 농산물선물Enhanced(H)',
#     'nowVal': 5560,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.98,
#     'nav': None,
#     'threeMonthEarnRate': 22.7322,
#     'quant': 63030,
#     'amonut': 350,
#     'marketSum': 500},
#    {'itemcode': '130730',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 단기자금',
#     'nowVal': 100905,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.01,
#     'nav': 100906.0,
#     'threeMonthEarnRate': 0.1429,
#     'quant': 237193,
#     'amonut': 23933,
#     'marketSum': 485},
#    {'itemcode': '122260',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 통안채1년',
#     'nowVal': 101120,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.01,
#     'nav': 101115.0,
#     'threeMonthEarnRate': 0.2508,
#     'quant': 546820,
#     'amonut': 55286,
#     'marketSum': 475},
#    {'itemcode': '305080',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국채10년선물',
#     'nowVal': 11655,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.3,
#     'nav': None,
#     'threeMonthEarnRate': -2.38,
#     'quant': 44710,
#     'amonut': 520,
#     'marketSum': 466},
#    {'itemcode': '292050',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR KRX300',
#     'nowVal': 20105,
#     'risefall': '2',
#     'changeVal': 210,
#     'changeRate': 1.06,
#     'nav': 20102.0,
#     'threeMonthEarnRate': 38.4963,
#     'quant': 10624,
#     'amonut': 212,
#     'marketSum': 462},
#    {'itemcode': '365000',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX인터넷K-뉴딜',
#     'nowVal': 11515,
#     'risefall': '2',
#     'changeVal': 235,
#     'changeRate': 2.08,
#     'nav': 11583.0,
#     'threeMonthEarnRate': 18.8619,
#     'quant': 129331,
#     'amonut': 1477,
#     'marketSum': 461},
#    {'itemcode': '245340',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국다우존스30',
#     'nowVal': 17225,
#     'risefall': '2',
#     'changeVal': 220,
#     'changeRate': 1.29,
#     'nav': None,
#     'threeMonthEarnRate': 12.8925,
#     'quant': 20446,
#     'amonut': 351,
#     'marketSum': 448},
#    {'itemcode': '117700',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 건설',
#     'nowVal': 3230,
#     'risefall': '2',
#     'changeVal': 110,
#     'changeRate': 3.53,
#     'nav': 3229.0,
#     'threeMonthEarnRate': 36.8421,
#     'quant': 775675,
#     'amonut': 2465,
#     'marketSum': 439},
#    {'itemcode': '359210',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스피TR',
#     'nowVal': 14395,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 0.52,
#     'nav': 14489.0,
#     'threeMonthEarnRate': 36.837,
#     'quant': 93,
#     'amonut': 1,
#     'marketSum': 432},
#    {'itemcode': '368590',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국나스닥100',
#     'nowVal': 11255,
#     'risefall': '2',
#     'changeVal': 170,
#     'changeRate': 1.53,
#     'nav': None,
#     'threeMonthEarnRate': None,
#     'quant': 775478,
#     'amonut': 8708,
#     'marketSum': 428},
#    {'itemcode': '272570',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 중장기국공채액티브',
#     'nowVal': 104305,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.04,
#     'nav': 104285.0,
#     'threeMonthEarnRate': 0.3416,
#     'quant': 142,
#     'amonut': 14,
#     'marketSum': 417},
#    {'itemcode': '364990',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX게임K-뉴딜',
#     'nowVal': 12510,
#     'risefall': '2',
#     'changeVal': 180,
#     'changeRate': 1.46,
#     'nav': 12540.0,
#     'threeMonthEarnRate': 32.3671,
#     'quant': 120199,
#     'amonut': 1491,
#     'marketSum': 413},
#    {'itemcode': '356540',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX KIS종합채권(AA-이상)액티브',
#     'nowVal': 99200,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 99218.0,
#     'threeMonthEarnRate': -0.5913,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 397},
#    {'itemcode': '139250',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 에너지화학',
#     'nowVal': 22715,
#     'risefall': '2',
#     'changeVal': 255,
#     'changeRate': 1.14,
#     'nav': 22726.0,
#     'threeMonthEarnRate': 61.3505,
#     'quant': 24617,
#     'amonut': 555,
#     'marketSum': 391},
#    {'itemcode': '304770',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 코스닥150',
#     'nowVal': 14980,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.37,
#     'nav': 15065.0,
#     'threeMonthEarnRate': 22.4364,
#     'quant': 1252,
#     'amonut': 18,
#     'marketSum': 377},
#    {'itemcode': '228810',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 미디어컨텐츠',
#     'nowVal': 6845,
#     'risefall': '2',
#     'changeVal': 105,
#     'changeRate': 1.56,
#     'nav': 6841.0,
#     'threeMonthEarnRate': 30.2415,
#     'quant': 206947,
#     'amonut': 1407,
#     'marketSum': 376},
#    {'itemcode': '371450',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌클라우드컴퓨팅INDXX',
#     'nowVal': 11410,
#     'risefall': '2',
#     'changeVal': 180,
#     'changeRate': 1.6,
#     'nav': None,
#     'threeMonthEarnRate': None,
#     'quant': 126931,
#     'amonut': 1446,
#     'marketSum': 374},
#    {'itemcode': '169950',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 중국본토 A50',
#     'nowVal': 24840,
#     'risefall': '2',
#     'changeVal': 180,
#     'changeRate': 0.73,
#     'nav': None,
#     'threeMonthEarnRate': 18.7861,
#     'quant': 20830,
#     'amonut': 514,
#     'marketSum': 373},
#    {'itemcode': '363570',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 장기종합채권(AA-이상)액티브KAP',
#     'nowVal': 98050,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 98056.0,
#     'threeMonthEarnRate': -1.2787,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 371},
#    {'itemcode': '099140',
#     'etfTabCode': 4,
#     'itemname': 'KODEX China H',
#     'nowVal': 23075,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.11,
#     'nav': None,
#     'threeMonthEarnRate': 14.4204,
#     'quant': 7684,
#     'amonut': 176,
#     'marketSum': 369},
#    {'itemcode': '306520',
#     'etfTabCode': 3,
#     'itemname': 'HANARO 200선물인버스',
#     'nowVal': 8865,
#     'risefall': '5',
#     'changeVal': -80,
#     'changeRate': -0.89,
#     'nav': 8868.0,
#     'threeMonthEarnRate': -29.5947,
#     'quant': 18621,
#     'amonut': 165,
#     'marketSum': 368},
#    {'itemcode': '304940',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100선물(H)',
#     'nowVal': 17245,
#     'risefall': '2',
#     'changeVal': 300,
#     'changeRate': 1.77,
#     'nav': None,
#     'threeMonthEarnRate': 19.9221,
#     'quant': 52765,
#     'amonut': 907,
#     'marketSum': 354},
#    {'itemcode': '329750',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국달러단기채권액티브',
#     'nowVal': 9555,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.16,
#     'nav': None,
#     'threeMonthEarnRate': -1.4926,
#     'quant': 101042,
#     'amonut': 964,
#     'marketSum': 353},
#    {'itemcode': '280930',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국러셀2000(H)',
#     'nowVal': 13985,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 0.61,
#     'nav': None,
#     'threeMonthEarnRate': 38.0337,
#     'quant': 34927,
#     'amonut': 487,
#     'marketSum': 350},
#    {'itemcode': '114100',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 국고채3년',
#     'nowVal': 113565,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': 0.0,
#     'nav': 113569.0,
#     'threeMonthEarnRate': 0.3179,
#     'quant': 1026,
#     'amonut': 116,
#     'marketSum': 341},
#    {'itemcode': '261250',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 미국달러선물레버리지',
#     'nowVal': 9035,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.22,
#     'nav': 9032.0,
#     'threeMonthEarnRate': -2.8955,
#     'quant': 59849,
#     'amonut': 539,
#     'marketSum': 341},
#    {'itemcode': '114470',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 국고채3년',
#     'nowVal': 112975,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.05,
#     'nav': 112982.0,
#     'threeMonthEarnRate': 0.1729,
#     'quant': 253,
#     'amonut': 28,
#     'marketSum': 339},
#    {'itemcode': '292160',
#     'etfTabCode': 1,
#     'itemname': 'TIGER KRX300',
#     'nowVal': 19860,
#     'risefall': '2',
#     'changeVal': 180,
#     'changeRate': 0.91,
#     'nav': 19862.0,
#     'threeMonthEarnRate': 38.7968,
#     'quant': 430,
#     'amonut': 8,
#     'marketSum': 338},
#    {'itemcode': '204450',
#     'etfTabCode': 4,
#     'itemname': 'KODEX China H 레버리지(H)',
#     'nowVal': 8195,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.18,
#     'nav': None,
#     'threeMonthEarnRate': 35.7024,
#     'quant': 34159,
#     'amonut': 277,
#     'marketSum': 336},
#    {'itemcode': '289040',
#     'etfTabCode': 2,
#     'itemname': 'KODEX MSCI KOREA ESG유니버설',
#     'nowVal': 12860,
#     'risefall': '2',
#     'changeVal': 115,
#     'changeRate': 0.9,
#     'nav': 12926.0,
#     'threeMonthEarnRate': 38.4573,
#     'quant': 3530,
#     'amonut': 45,
#     'marketSum': 334},
#    {'itemcode': '252400',
#     'etfTabCode': 3,
#     'itemname': 'KBSTAR 200선물레버리지',
#     'nowVal': 25315,
#     'risefall': '2',
#     'changeVal': 425,
#     'changeRate': 1.71,
#     'nav': 25347.0,
#     'threeMonthEarnRate': 92.1265,
#     'quant': 42158,
#     'amonut': 1061,
#     'marketSum': 329},
#    {'itemcode': '203780',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국나스닥바이오',
#     'nowVal': 21190,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.05,
#     'nav': None,
#     'threeMonthEarnRate': 22.8467,
#     'quant': 19229,
#     'amonut': 408,
#     'marketSum': 318},
#    {'itemcode': '123320',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 레버리지',
#     'nowVal': 26320,
#     'risefall': '2',
#     'changeVal': 460,
#     'changeRate': 1.78,
#     'nav': 26355.0,
#     'threeMonthEarnRate': 92.7692,
#     'quant': 209352,
#     'amonut': 5478,
#     'marketSum': 316},
#    {'itemcode': '354500',
#     'etfTabCode': 1,
#     'itemname': 'KINDEX 코스닥150',
#     'nowVal': 15025,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 0.57,
#     'nav': 15057.0,
#     'threeMonthEarnRate': 22.1087,
#     'quant': 646,
#     'amonut': 9,
#     'marketSum': 316},
#    {'itemcode': '316670',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 코스닥150',
#     'nowVal': 7460,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 7489.0,
#     'threeMonthEarnRate': 22.4958,
#     'quant': 532,
#     'amonut': 3,
#     'marketSum': 307},
#    {'itemcode': '276650',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 글로벌4차산업IT(합성 H)',
#     'nowVal': 20730,
#     'risefall': '2',
#     'changeVal': 200,
#     'changeRate': 0.97,
#     'nav': None,
#     'threeMonthEarnRate': 21.1924,
#     'quant': 16485,
#     'amonut': 341,
#     'marketSum': 290},
#    {'itemcode': '250780',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 코스닥150선물인버스',
#     'nowVal': 4540,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.22,
#     'nav': 4545.0,
#     'threeMonthEarnRate': -20.4546,
#     'quant': 894665,
#     'amonut': 4082,
#     'marketSum': 288},
#    {'itemcode': '152870',
#     'etfTabCode': 1,
#     'itemname': '파워 200',
#     'nowVal': 44035,
#     'risefall': '2',
#     'changeVal': 400,
#     'changeRate': 0.92,
#     'nav': 44084.0,
#     'threeMonthEarnRate': 40.2152,
#     'quant': 459,
#     'amonut': 20,
#     'marketSum': 286},
#    {'itemcode': '252420',
#     'etfTabCode': 3,
#     'itemname': 'KBSTAR 200선물인버스2X',
#     'nowVal': 2055,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -1.91,
#     'nav': 2052.0,
#     'threeMonthEarnRate': -51.1656,
#     'quant': 1330950,
#     'amonut': 2752,
#     'marketSum': 284},
#    {'itemcode': '138230',
#     'etfTabCode': 7,
#     'itemname': 'KOSEF 미국달러선물',
#     'nowVal': 11745,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.04,
#     'nav': 11742.0,
#     'threeMonthEarnRate': -1.6408,
#     'quant': 6072,
#     'amonut': 71,
#     'marketSum': 283},
#    {'itemcode': '361580',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 200TR',
#     'nowVal': 21745,
#     'risefall': '2',
#     'changeVal': 200,
#     'changeRate': 0.93,
#     'nav': 21762.0,
#     'threeMonthEarnRate': 40.2669,
#     'quant': 968,
#     'amonut': 20,
#     'marketSum': 283},
#    {'itemcode': '223190',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 200가치저변동',
#     'nowVal': 10845,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.56,
#     'nav': 10901.0,
#     'threeMonthEarnRate': 31.4442,
#     'quant': 17074,
#     'amonut': 184,
#     'marketSum': 282},
#    {'itemcode': '269540',
#     'etfTabCode': 4,
#     'itemname': 'ARIRANG 미국S&P500(H)',
#     'nowVal': 15620,
#     'risefall': '2',
#     'changeVal': 225,
#     'changeRate': 1.46,
#     'nav': None,
#     'threeMonthEarnRate': 15.578,
#     'quant': 13588,
#     'amonut': 212,
#     'marketSum': 281},
#    {'itemcode': '217780',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나CSI300인버스(합성)',
#     'nowVal': 7270,
#     'risefall': '5',
# ...
#     'itemname': 'KINDEX 필리핀MSCI(합성)',
#     'nowVal': 13620,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.44,
#     'nav': None,
#     'threeMonthEarnRate': 9.2227,
#     'quant': 201,
#     'amonut': 2,
#     'marketSum': 54},
#    {'itemcode': '250730',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 차이나HSCEI(H)',
#     'nowVal': 13315,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': None,
#     'threeMonthEarnRate': 16.5936,
#     'quant': 2566,
#     'amonut': 33,
#     'marketSum': 53},
#    {'itemcode': '301410',
#     'etfTabCode': 3,
#     'itemname': 'ARIRANG 코스닥150선물인버스',
#     'nowVal': 7025,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.43,
#     'nav': 7028.0,
#     'threeMonthEarnRate': -20.3725,
#     'quant': 31736,
#     'amonut': 223,
#     'marketSum': 53},
#    {'itemcode': '334690',
#     'etfTabCode': 5,
#     'itemname': 'KBSTAR 팔라듐선물(H)',
#     'nowVal': 13055,
#     'risefall': '5',
#     'changeVal': -85,
#     'changeRate': -0.65,
#     'nav': None,
#     'threeMonthEarnRate': -1.3884,
#     'quant': 12069,
#     'amonut': 157,
#     'marketSum': 52},
#    {'itemcode': '326230',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 내수주플러스',
#     'nowVal': 10845,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.42,
#     'nav': 10917.0,
#     'threeMonthEarnRate': 18.2913,
#     'quant': 2247,
#     'amonut': 24,
#     'marketSum': 52},
#    {'itemcode': '300610',
#     'etfTabCode': 2,
#     'itemname': 'TIGER K게임',
#     'nowVal': 13000,
#     'risefall': '2',
#     'changeVal': 205,
#     'changeRate': 1.6,
#     'nav': 13009.0,
#     'threeMonthEarnRate': 25.997,
#     'quant': 6009,
#     'amonut': 77,
#     'marketSum': 52},
#    {'itemcode': '284990',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200에너지화학',
#     'nowVal': 15050,
#     'risefall': '2',
#     'changeVal': 190,
#     'changeRate': 1.28,
#     'nav': 15043.0,
#     'threeMonthEarnRate': 60.9095,
#     'quant': 7767,
#     'amonut': 116,
#     'marketSum': 51},
#    {'itemcode': '091220',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 은행',
#     'nowVal': 6350,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.32,
#     'nav': 6357.0,
#     'threeMonthEarnRate': 6.1012,
#     'quant': 25537,
#     'amonut': 163,
#     'marketSum': 51},
#    {'itemcode': '292770',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국채선물3년인버스',
#     'nowVal': 49640,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 49628.0,
#     'threeMonthEarnRate': 0.1412,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 51},
#    {'itemcode': '269370',
#     'etfTabCode': 4,
#     'itemname': 'TIGER S&P글로벌인프라(합성)',
#     'nowVal': 9945,
#     'risefall': '2',
#     'changeVal': 185,
#     'changeRate': 1.9,
#     'nav': None,
#     'threeMonthEarnRate': 12.2355,
#     'quant': 169,
#     'amonut': 1,
#     'marketSum': 50},
#    {'itemcode': '217770',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 원유선물인버스(H)',
#     'nowVal': 8285,
#     'risefall': '5',
#     'changeVal': -110,
#     'changeRate': -1.31,
#     'nav': None,
#     'threeMonthEarnRate': -36.9982,
#     'quant': 1778,
#     'amonut': 14,
#     'marketSum': 50},
#    {'itemcode': '299080',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 국채선물3년인버스',
#     'nowVal': 99170,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 99156.0,
#     'threeMonthEarnRate': 0.0252,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 50},
#    {'itemcode': '333950',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG KS로우사이즈가중TR',
#     'nowVal': 16465,
#     'risefall': '2',
#     'changeVal': 255,
#     'changeRate': 1.57,
#     'nav': 16462.0,
#     'threeMonthEarnRate': 34.3555,
#     'quant': 222,
#     'amonut': 3,
#     'marketSum': 49},
#    {'itemcode': '292340',
#     'etfTabCode': 2,
#     'itemname': '마이티 200커버드콜ATM레버리지',
#     'nowVal': 9840,
#     'risefall': '2',
#     'changeVal': 95,
#     'changeRate': 0.97,
#     'nav': 9929.0,
#     'threeMonthEarnRate': 20.7558,
#     'quant': 183,
#     'amonut': 1,
#     'marketSum': 49},
#    {'itemcode': '275750',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스닥150선물인버스',
#     'nowVal': 4685,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 4682.0,
#     'threeMonthEarnRate': -20.5259,
#     'quant': 30321,
#     'amonut': 142,
#     'marketSum': 49},
#    {'itemcode': '307520',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 지주회사',
#     'nowVal': 12265,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.49,
#     'nav': 12259.0,
#     'threeMonthEarnRate': 27.935,
#     'quant': 5749,
#     'amonut': 69,
#     'marketSum': 49},
#    {'itemcode': '261260',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 미국달러선물인버스2X',
#     'nowVal': 10080,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.4,
#     'nav': 10084.0,
#     'threeMonthEarnRate': 2.2403,
#     'quant': 6221,
#     'amonut': 62,
#     'marketSum': 48},
#    {'itemcode': '290080',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200고배당커버드콜ATM',
#     'nowVal': 6865,
#     'risefall': '2',
#     'changeVal': 95,
#     'changeRate': 1.4,
#     'nav': 6856.0,
#     'threeMonthEarnRate': -5.9723,
#     'quant': 67,
#     'amonut': 0,
#     'marketSum': 48},
#    {'itemcode': '299070',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 국채선물10년인버스',
#     'nowVal': 94000,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 94059.0,
#     'threeMonthEarnRate': 1.1133,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 47},
#    {'itemcode': '291610',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 코스닥150선물',
#     'nowVal': 9750,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.36,
#     'nav': 9734.0,
#     'threeMonthEarnRate': 23.2868,
#     'quant': 3151,
#     'amonut': 30,
#     'marketSum': 47},
#    {'itemcode': '244670',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 밸류Plus',
#     'nowVal': 9285,
#     'risefall': '2',
#     'changeVal': 110,
#     'changeRate': 1.2,
#     'nav': 9324.0,
#     'threeMonthEarnRate': 26.5517,
#     'quant': 557,
#     'amonut': 5,
#     'marketSum': 46},
#    {'itemcode': '291660',
#     'etfTabCode': 4,
#     'itemname': 'KODEX China H선물인버스(H)',
#     'nowVal': 9140,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.44,
#     'nav': None,
#     'threeMonthEarnRate': -16.0517,
#     'quant': 114,
#     'amonut': 1,
#     'marketSum': 46},
#    {'itemcode': '252410',
#     'etfTabCode': 3,
#     'itemname': 'KBSTAR 200선물인버스',
#     'nowVal': 5000,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.99,
#     'nav': 4990.0,
#     'threeMonthEarnRate': -29.3213,
#     'quant': 14883,
#     'amonut': 74,
#     'marketSum': 45},
#    {'itemcode': '252720',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 모멘텀밸류',
#     'nowVal': 14720,
#     'risefall': '2',
#     'changeVal': 125,
#     'changeRate': 0.86,
#     'nav': 14783.0,
#     'threeMonthEarnRate': 37.6886,
#     'quant': 1165,
#     'amonut': 17,
#     'marketSum': 44},
#    {'itemcode': '295820',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 200동일가중',
#     'nowVal': 11000,
#     'risefall': '2',
#     'changeVal': 180,
#     'changeRate': 1.66,
#     'nav': 10994.0,
#     'threeMonthEarnRate': 29.1169,
#     'quant': 193,
#     'amonut': 2,
#     'marketSum': 44},
#    {'itemcode': '304670',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국채울트라30년선물인버스(H)',
#     'nowVal': 7300,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.41,
#     'nav': None,
#     'threeMonthEarnRate': 3.1937,
#     'quant': 1399,
#     'amonut': 10,
#     'marketSum': 44},
#    {'itemcode': '271050',
#     'etfTabCode': 5,
#     'itemname': 'KODEX WTI원유선물인버스(H)',
#     'nowVal': 11655,
#     'risefall': '5',
#     'changeVal': -145,
#     'changeRate': -1.23,
#     'nav': None,
#     'threeMonthEarnRate': -36.0607,
#     'quant': 14670,
#     'amonut': 170,
#     'marketSum': 44},
#    {'itemcode': '287330',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200생활소비재',
#     'nowVal': 8895,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.74,
#     'nav': 8894.0,
#     'threeMonthEarnRate': 14.3782,
#     'quant': 161,
#     'amonut': 1,
#     'marketSum': 43},
#    {'itemcode': '291620',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 코스닥150선물인버스',
#     'nowVal': 8040,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.43,
#     'nav': 8040.0,
#     'threeMonthEarnRate': -20.1681,
#     'quant': 7536,
#     'amonut': 60,
#     'marketSum': 43},
#    {'itemcode': '227560',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 생활소비재',
#     'nowVal': 11680,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.56,
#     'nav': 11676.0,
#     'threeMonthEarnRate': 15.0,
#     'quant': 14697,
#     'amonut': 171,
#     'marketSum': 42},
#    {'itemcode': '321410',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 멀티에셋하이인컴(H)',
#     'nowVal': 10400,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.43,
#     'nav': None,
#     'threeMonthEarnRate': 6.2051,
#     'quant': 913,
#     'amonut': 9,
#     'marketSum': 42},
#    {'itemcode': '227550',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 산업재',
#     'nowVal': 5920,
#     'risefall': '2',
#     'changeVal': 80,
#     'changeRate': 1.37,
#     'nav': 5952.0,
#     'threeMonthEarnRate': 34.5622,
#     'quant': 2819,
#     'amonut': 16,
#     'marketSum': 41},
#    {'itemcode': '292570',
#     'etfTabCode': 7,
#     'itemname': 'TIGER 일본엔선물레버리지',
#     'nowVal': 10355,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.1,
#     'nav': 10335.0,
#     'threeMonthEarnRate': -3.9389,
#     'quant': 219,
#     'amonut': 2,
#     'marketSum': 41},
#    {'itemcode': '267490',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국장기국채선물레버리지(합성 H)',
#     'nowVal': 13575,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -0.51,
#     'nav': None,
#     'threeMonthEarnRate': -6.0586,
#     'quant': 505,
#     'amonut': 6,
#     'marketSum': 41},
#    {'itemcode': '253240',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 200선물인버스',
#     'nowVal': 5005,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.99,
#     'nav': 4986.0,
#     'threeMonthEarnRate': -29.4488,
#     'quant': 16302,
#     'amonut': 81,
#     'marketSum': 41},
#    {'itemcode': '278420',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG ESG우수기업',
#     'nowVal': 8995,
#     'risefall': '2',
#     'changeVal': 120,
#     'changeRate': 1.35,
#     'nav': 9016.0,
#     'threeMonthEarnRate': 17.2391,
#     'quant': 2876,
#     'amonut': 25,
#     'marketSum': 40},
#    {'itemcode': '267450',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국장기국채선물인버스(H)',
#     'nowVal': 7915,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.19,
#     'nav': None,
#     'threeMonthEarnRate': 2.4643,
#     'quant': 11,
#     'amonut': 0,
#     'marketSum': 40},
#    {'itemcode': '300280',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 중소형모멘텀로우볼',
#     'nowVal': 11185,
#     'risefall': '2',
#     'changeVal': 215,
#     'changeRate': 1.96,
#     'nav': 11199.0,
#     'threeMonthEarnRate': 21.9566,
#     'quant': 5,
#     'amonut': 0,
#     'marketSum': 39},
#    {'itemcode': '140570',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 수출주',
#     'nowVal': 13035,
#     'risefall': '2',
#     'changeVal': 195,
#     'changeRate': 1.52,
#     'nav': 13036.0,
#     'threeMonthEarnRate': 42.3503,
#     'quant': 125,
#     'amonut': 1,
#     'marketSum': 39},
#    {'itemcode': '295020',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 국채선물10년인버스',
#     'nowVal': 46895,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.05,
#     'nav': 46877.0,
#     'threeMonthEarnRate': 1.0891,
#     'quant': 6,
#     'amonut': 0,
#     'marketSum': 38},
#    {'itemcode': '292580',
#     'etfTabCode': 7,
#     'itemname': 'TIGER 일본엔선물인버스',
#     'nowVal': 9410,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.58,
#     'nav': 9468.0,
#     'threeMonthEarnRate': 1.7741,
#     'quant': 10001,
#     'amonut': 94,
#     'marketSum': 38},
#    {'itemcode': '301400',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 코스닥150',
#     'nowVal': 14960,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.37,
#     'nav': 15047.0,
#     'threeMonthEarnRate': 22.3225,
#     'quant': 4506,
#     'amonut': 67,
#     'marketSum': 37},
#    {'itemcode': '269530',
#     'etfTabCode': 4,
#     'itemname': 'ARIRANG S&P글로벌인프라',
#     'nowVal': 10430,
#     'risefall': '2',
#     'changeVal': 115,
#     'changeRate': 1.11,
#     'nav': None,
#     'threeMonthEarnRate': 9.734,
#     'quant': 1895,
#     'amonut': 19,
#     'marketSum': 37},
#    {'itemcode': '139240',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 철강소재',
#     'nowVal': 7565,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.13,
#     'nav': 7583.0,
#     'threeMonthEarnRate': 26.1448,
#     'quant': 8725,
#     'amonut': 65,
#     'marketSum': 36},
#    {'itemcode': '291680',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 차이나H선물인버스(H)',
#     'nowVal': 8980,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.56,
#     'nav': None,
#     'threeMonthEarnRate': -16.4249,
#     'quant': 158,
#     'amonut': 1,
#     'marketSum': 36},
#    {'itemcode': '280940',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 골드선물인버스(H)',
#     'nowVal': 7140,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 1.2,
#     'nav': None,
#     'threeMonthEarnRate': 0.427,
#     'quant': 4442,
#     'amonut': 31,
#     'marketSum': 36},
#    {'itemcode': '140580',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 우량업종',
#     'nowVal': 11725,
#     'risefall': '2',
#     'changeVal': 100,
#     'changeRate': 0.86,
#     'nav': 11740.0,
#     'threeMonthEarnRate': 25.4045,
#     'quant': 618,
#     'amonut': 7,
#     'marketSum': 35},
#    {'itemcode': '292590',
#     'etfTabCode': 7,
#     'itemname': 'TIGER 일본엔선물인버스2X',
#     'nowVal': 8510,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.29,
#     'nav': 8510.0,
#     'threeMonthEarnRate': 2.9108,
#     'quant': 255,
#     'amonut': 2,
#     'marketSum': 34},
#    {'itemcode': '139310',
#     'etfTabCode': 5,
#     'itemname': 'TIGER 금속선물(H)',
#     'nowVal': 5595,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.09,
#     'nav': None,
#     'threeMonthEarnRate': 11.665,
#     'quant': 1541,
#     'amonut': 8,
#     'marketSum': 34},
#    {'itemcode': '309170',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG KRX300IT',
#     'nowVal': 20715,
#     'risefall': '2',
#     'changeVal': 135,
#     'changeRate': 0.66,
#     'nav': 20712.0,
#     'threeMonthEarnRate': 52.614,
#     'quant': 283,
#     'amonut': 5,
#     'marketSum': 29},
#    {'itemcode': '287310',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200경기소비재',
#     'nowVal': 12715,
#     'risefall': '2',
#     'changeVal': 485,
#     'changeRate': 3.97,
#     'nav': 12766.0,
#     'threeMonthEarnRate': 39.9313,
#     'quant': 1774,
#     'amonut': 22,
#     'marketSum': 25},
#    {'itemcode': '284980',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200금융',
#     'nowVal': 7705,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.46,
#     'nav': 7707.0,
#     'threeMonthEarnRate': 8.4865,
#     'quant': 4289,
#     'amonut': 33,
#     'marketSum': 23},
#    {'itemcode': '285010',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200중공업',
#     'nowVal': 8485,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.24,
#     'nav': 8481.0,
#     'threeMonthEarnRate': 16.7586,
#     'quant': 282,
#     'amonut': 2,
#     'marketSum': 22},
#    {'itemcode': '334700',
#     'etfTabCode': 5,
#     'itemname': 'KBSTAR 팔라듐선물인버스(H)',
#     'nowVal': 5495,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.55,
#     'nav': None,
#     'threeMonthEarnRate': -1.5316,
#     'quant': 1816,
#     'amonut': 9,
#     'marketSum': 22},
#    {'itemcode': '267500',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국장기국채선물인버스2X(합성 H)',
#     'nowVal': 6030,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.5,
#     'nav': None,
#     'threeMonthEarnRate': 4.8951,
#     'quant': 4614,
#     'amonut': 27,
#     'marketSum': 18},
#    {'itemcode': '285020',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200철강소재',
#     'nowVal': 7245,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.35,
#     'nav': 7246.0,
#     'threeMonthEarnRate': 25.5652,
#     'quant': 3443,
#     'amonut': 24,
#     'marketSum': 17},
#    {'itemcode': '287320',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200산업재',
#     'nowVal': 10750,
#     'risefall': '2',
#     'changeVal': 220,
#     'changeRate': 2.09,
#     'nav': 10776.0,
#     'threeMonthEarnRate': 33.1226,
#     'quant': 47,
#     'amonut': 0,
#     'marketSum': 13}]}}

# %% [markdown]
# <br>
#
# ### 7.3.5 JSON에서 원하는 데이터 찾기

# %%
etf_json['resultCode']
# Out:
# 'success'

# %%
etfItemList = etf_json['result']['etfItemList']
etfItemList
# Out:
# [{'itemcode': '069500',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 200',
#   'nowVal': 43130,
#   'risefall': '2',
#   'changeVal': 355,
#   'changeRate': 0.83,
#   'nav': 43214.0,
#   'threeMonthEarnRate': 39.9522,
#   'quant': 8521906,
#   'amonut': 366352,
#   'marketSum': 62625},
#  {'itemcode': '102110',
#   'etfTabCode': 1,
#   'itemname': 'TIGER 200',
#   'nowVal': 42970,
#   'risefall': '2',
#   'changeVal': 360,
#   'changeRate': 0.84,
#   'nav': 43038.0,
#   'threeMonthEarnRate': 39.971,
#   'quant': 1650818,
#   'amonut': 70651,
#   'marketSum': 31347},
#  {'itemcode': '252670',
#   'etfTabCode': 3,
#   'itemname': 'KODEX 200선물인버스2X',
#   'nowVal': 2055,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -1.67,
#   'nav': 2051.0,
#   'threeMonthEarnRate': -51.2821,
#   'quant': 642008913,
#   'amonut': 1329284,
#   'marketSum': 20227},
#  {'itemcode': '122630',
#   'etfTabCode': 3,
#   'itemname': 'KODEX 레버리지',
#   'nowVal': 27825,
#   'risefall': '2',
#   'changeVal': 475,
#   'changeRate': 1.74,
#   'nav': 28022.0,
#   'threeMonthEarnRate': 92.0646,
#   'quant': 46157932,
#   'amonut': 1275107,
#   'marketSum': 19088},
#  {'itemcode': '102780',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 삼성그룹',
#   'nowVal': 10530,
#   'risefall': '2',
#   'changeVal': 70,
#   'changeRate': 0.67,
#   'nav': 10545.0,
#   'threeMonthEarnRate': 37.6315,
#   'quant': 612363,
#   'amonut': 6415,
#   'marketSum': 18522},
#  {'itemcode': '278530',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 200TR',
#   'nowVal': 13900,
#   'risefall': '2',
#   'changeVal': 125,
#   'changeRate': 0.91,
#   'nav': 13910.0,
#   'threeMonthEarnRate': 40.1322,
#   'quant': 358712,
#   'amonut': 4968,
#   'marketSum': 17577},
#  {'itemcode': '153130',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 단기채권',
#   'nowVal': 102690,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.01,
#   'nav': 102685.0,
#   'threeMonthEarnRate': 0.1316,
#   'quant': 15291,
#   'amonut': 1570,
#   'marketSum': 17437},
#  {'itemcode': '278540',
#   'etfTabCode': 1,
#   'itemname': 'KODEX MSCI Korea TR',
#   'nowVal': 13900,
#   'risefall': '2',
#   'changeVal': 85,
#   'changeRate': 0.62,
#   'nav': 13948.0,
#   'threeMonthEarnRate': 40.8975,
#   'quant': 276979,
#   'amonut': 3854,
#   'marketSum': 17278},
#  {'itemcode': '310970',
#   'etfTabCode': 1,
#   'itemname': 'TIGER MSCI Korea TR',
#   'nowVal': 17525,
#   'risefall': '2',
#   'changeVal': 150,
#   'changeRate': 0.86,
#   'nav': 17518.0,
#   'threeMonthEarnRate': 41.3176,
#   'quant': 207514,
#   'amonut': 3620,
#   'marketSum': 16491},
#  {'itemcode': '273130',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 종합채권(AA-이상)액티브',
#   'nowVal': 109870,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.01,
#   'nav': 109830.0,
#   'threeMonthEarnRate': -0.4576,
#   'quant': 6949,
#   'amonut': 763,
#   'marketSum': 14997},
#  {'itemcode': '148020',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 200',
#   'nowVal': 43265,
#   'risefall': '2',
#   'changeVal': 400,
#   'changeRate': 0.93,
#   'nav': 43308.0,
#   'threeMonthEarnRate': 40.1412,
#   'quant': 654373,
#   'amonut': 28209,
#   'marketSum': 13153},
#  {'itemcode': '114800',
#   'etfTabCode': 3,
#   'itemname': 'KODEX 인버스',
#   'nowVal': 3865,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -0.9,
#   'nav': 3868.0,
#   'threeMonthEarnRate': -29.6664,
#   'quant': 104465568,
#   'amonut': 405762,
#   'marketSum': 12252},
#  {'itemcode': '233740',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 코스닥150 레버리지',
#   'nowVal': 16205,
#   'risefall': '2',
#   'changeVal': 125,
#   'changeRate': 0.78,
#   'nav': 16339.0,
#   'threeMonthEarnRate': 47.5906,
#   'quant': 16490755,
#   'amonut': 263501,
#   'marketSum': 11651},
#  {'itemcode': '305720',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 2차전지산업',
#   'nowVal': 20175,
#   'risefall': '2',
#   'changeVal': 325,
#   'changeRate': 1.64,
#   'nav': 20250.0,
#   'threeMonthEarnRate': 74.4288,
#   'quant': 4103690,
#   'amonut': 82498,
#   'marketSum': 10390},
#  {'itemcode': '152100',
#   'etfTabCode': 1,
#   'itemname': 'ARIRANG 200',
#   'nowVal': 43450,
#   'risefall': '2',
#   'changeVal': 360,
#   'changeRate': 0.84,
#   'nav': 43534.0,
#   'threeMonthEarnRate': 40.1574,
#   'quant': 130861,
#   'amonut': 5679,
#   'marketSum': 8581},
#  {'itemcode': '292150',
#   'etfTabCode': 2,
#   'itemname': 'TIGER TOP10',
#   'nowVal': 15440,
#   'risefall': '2',
#   'changeVal': 185,
#   'changeRate': 1.21,
#   'nav': 15436.0,
#   'threeMonthEarnRate': 48.3228,
#   'quant': 878431,
#   'amonut': 13482,
#   'marketSum': 8376},
#  {'itemcode': '139260',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 IT',
#   'nowVal': 40980,
#   'risefall': '2',
#   'changeVal': 425,
#   'changeRate': 1.05,
#   'nav': 40976.0,
#   'threeMonthEarnRate': 58.9768,
#   'quant': 433317,
#   'amonut': 17640,
#   'marketSum': 8171},
#  {'itemcode': '214980',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 단기채권PLUS',
#   'nowVal': 102950,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.01,
#   'nav': 102944.0,
#   'threeMonthEarnRate': 0.1605,
#   'quant': 4787,
#   'amonut': 492,
#   'marketSum': 8146},
#  {'itemcode': '105190',
#   'etfTabCode': 1,
#   'itemname': 'KINDEX 200',
#   'nowVal': 43425,
#   'risefall': '2',
#   'changeVal': 385,
#   'changeRate': 0.89,
#   'nav': 43485.0,
#   'threeMonthEarnRate': 40.1497,
#   'quant': 284592,
#   'amonut': 12286,
#   'marketSum': 7708},
#  {'itemcode': '364980',
#   'etfTabCode': 2,
#   'itemname': 'TIGER KRX2차전지K-뉴딜',
#   'nowVal': 18515,
#   'risefall': '2',
#   'changeVal': 255,
#   'changeRate': 1.4,
#   'nav': 18514.0,
#   'threeMonthEarnRate': 87.0901,
#   'quant': 2648744,
#   'amonut': 48749,
#   'marketSum': 7600},
#  {'itemcode': '305540',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 2차전지테마',
#   'nowVal': 18315,
#   'risefall': '2',
#   'changeVal': 290,
#   'changeRate': 1.61,
#   'nav': 18387.0,
#   'threeMonthEarnRate': 69.1694,
#   'quant': 2867117,
#   'amonut': 52278,
#   'marketSum': 6969},
#  {'itemcode': '157450',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 단기통안채',
#   'nowVal': 100065,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.0,
#   'nav': 100062.0,
#   'threeMonthEarnRate': 0.115,
#   'quant': 5066,
#   'amonut': 506,
#   'marketSum': 6632},
#  {'itemcode': '069660',
#   'etfTabCode': 1,
#   'itemname': 'KOSEF 200',
#   'nowVal': 43290,
#   'risefall': '2',
#   'changeVal': 375,
#   'changeRate': 0.87,
#   'nav': 43357.0,
#   'threeMonthEarnRate': 40.1306,
#   'quant': 177623,
#   'amonut': 7657,
#   'marketSum': 6580},
#  {'itemcode': '293180',
#   'etfTabCode': 1,
#   'itemname': 'HANARO 200',
#   'nowVal': 43130,
#   'risefall': '2',
#   'changeVal': 345,
#   'changeRate': 0.81,
#   'nav': 43200.0,
#   'threeMonthEarnRate': 40.0124,
#   'quant': 55121,
#   'amonut': 2370,
#   'marketSum': 6426},
#  {'itemcode': '133690',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국나스닥100',
#   'nowVal': 67650,
#   'risefall': '2',
#   'changeVal': 1040,
#   'changeRate': 1.56,
#   'nav': None,
#   'threeMonthEarnRate': 18.4493,
#   'quant': 118273,
#   'amonut': 7975,
#   'marketSum': 6359},
#  {'itemcode': '294400',
#   'etfTabCode': 1,
#   'itemname': 'KOSEF 200TR',
#   'nowVal': 50440,
#   'risefall': '2',
#   'changeVal': 415,
#   'changeRate': 0.83,
#   'nav': 50525.0,
#   'threeMonthEarnRate': 40.2242,
#   'quant': 18814,
#   'amonut': 946,
#   'marketSum': 4767},
#  {'itemcode': '295040',
#   'etfTabCode': 1,
#   'itemname': 'SMART 200TR',
#   'nowVal': 14435,
#   'risefall': '2',
#   'changeVal': 110,
#   'changeRate': 0.77,
#   'nav': 14467.0,
#   'threeMonthEarnRate': 40.3723,
#   'quant': 26535,
#   'amonut': 381,
#   'marketSum': 4612},
#  {'itemcode': '332940',
#   'etfTabCode': 1,
#   'itemname': 'HANARO MSCI Korea TR',
#   'nowVal': 17500,
#   'risefall': '2',
#   'changeVal': 205,
#   'changeRate': 1.19,
#   'nav': 17505.0,
#   'threeMonthEarnRate': 40.4955,
#   'quant': 55,
#   'amonut': 0,
#   'marketSum': 4463},
#  {'itemcode': '357870',
#   'etfTabCode': 7,
#   'itemname': 'TIGER CD금리투자KIS(합성)',
#   'nowVal': 50195,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 50197.0,
#   'threeMonthEarnRate': 0.1496,
#   'quant': 13,
#   'amonut': 0,
#   'marketSum': 4397},
#  {'itemcode': '371460',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나전기차SOLACTIVE',
#   'nowVal': 13660,
#   'risefall': '2',
#   'changeVal': 210,
#   'changeRate': 1.56,
#   'nav': None,
#   'threeMonthEarnRate': None,
#   'quant': 2183188,
#   'amonut': 29844,
#   'marketSum': 4393},
#  {'itemcode': '364960',
#   'etfTabCode': 2,
#   'itemname': 'TIGER KRX BBIG K-뉴딜',
#   'nowVal': 13885,
#   'risefall': '2',
#   'changeVal': 105,
#   'changeRate': 0.76,
#   'nav': 13931.0,
#   'threeMonthEarnRate': 42.4289,
#   'quant': 1452332,
#   'amonut': 20077,
#   'marketSum': 4277},
#  {'itemcode': '251340',
#   'etfTabCode': 3,
#   'itemname': 'KODEX 코스닥150선물인버스',
#   'nowVal': 4440,
#   'risefall': '5',
#   'changeVal': -15,
#   'changeRate': -0.34,
#   'nav': 4453.0,
#   'threeMonthEarnRate': -20.5883,
#   'quant': 55943952,
#   'amonut': 250588,
#   'marketSum': 4245},
#  {'itemcode': '261220',
#   'etfTabCode': 5,
#   'itemname': 'KODEX WTI원유선물(H)',
#   'nowVal': 8215,
#   'risefall': '2',
#   'changeVal': 105,
#   'changeRate': 1.29,
#   'nav': None,
#   'threeMonthEarnRate': 52.0149,
#   'quant': 1846418,
#   'amonut': 15192,
#   'marketSum': 4025},
#  {'itemcode': '315930',
#   'etfTabCode': 2,
#   'itemname': 'KODEX Top5PlusTR',
#   'nowVal': 19445,
#   'risefall': '2',
#   'changeVal': 175,
#   'changeRate': 0.91,
#   'nav': 19430.0,
#   'threeMonthEarnRate': 39.2844,
#   'quant': 9133,
#   'amonut': 176,
#   'marketSum': 4006},
#  {'itemcode': '226490',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 코스피',
#   'nowVal': 31925,
#   'risefall': '2',
#   'changeVal': 405,
#   'changeRate': 1.28,
#   'nav': 31927.0,
#   'threeMonthEarnRate': 36.6276,
#   'quant': 171220,
#   'amonut': 5436,
#   'marketSum': 3863},
#  {'itemcode': '229200',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 코스닥 150',
#   'nowVal': 15090,
#   'risefall': '2',
#   'changeVal': 75,
#   'changeRate': 0.5,
#   'nav': 15192.0,
#   'threeMonthEarnRate': 22.3716,
#   'quant': 2836019,
#   'amonut': 42442,
#   'marketSum': 3840},
#  {'itemcode': '314250',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국FANG플러스(H)',
#   'nowVal': 27280,
#   'risefall': '2',
#   'changeVal': 480,
#   'changeRate': 1.79,
#   'nav': None,
#   'threeMonthEarnRate': 25.0583,
#   'quant': 340070,
#   'amonut': 9245,
#   'marketSum': 3819},
#  {'itemcode': '251350',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 선진국MSCI World',
#   'nowVal': 16945,
#   'risefall': '2',
#   'changeVal': 150,
#   'changeRate': 0.89,
#   'nav': None,
#   'threeMonthEarnRate': 16.6724,
#   'quant': 18646,
#   'amonut': 315,
#   'marketSum': 3796},
#  {'itemcode': '091180',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 자동차',
#   'nowVal': 26230,
#   'risefall': '2',
#   'changeVal': 1220,
#   'changeRate': 4.88,
#   'nav': 26246.0,
#   'threeMonthEarnRate': 58.8945,
#   'quant': 2994541,
#   'amonut': 78317,
#   'marketSum': 3685},
#  {'itemcode': '192090',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나CSI300',
#   'nowVal': 12470,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.08,
#   'nav': None,
#   'threeMonthEarnRate': 16.8307,
#   'quant': 579804,
#   'amonut': 7238,
#   'marketSum': 3566},
#  {'itemcode': '332500',
#   'etfTabCode': 1,
#   'itemname': 'KINDEX 200TR',
#   'nowVal': 25880,
#   'risefall': '2',
#   'changeVal': 230,
#   'changeRate': 0.9,
#   'nav': 25902.0,
#   'threeMonthEarnRate': 40.2022,
#   'quant': 25954,
#   'amonut': 667,
#   'marketSum': 3416},
#  {'itemcode': '232080',
#   'etfTabCode': 1,
#   'itemname': 'TIGER 코스닥150',
#   'nowVal': 15160,
#   'risefall': '2',
#   'changeVal': 65,
#   'changeRate': 0.43,
#   'nav': 15270.0,
#   'threeMonthEarnRate': 22.1772,
#   'quant': 121785,
#   'amonut': 1833,
#   'marketSum': 2532},
#  {'itemcode': '132030',
#   'etfTabCode': 5,
#   'itemname': 'KODEX 골드선물(H)',
#   'nowVal': 12565,
#   'risefall': '5',
#   'changeVal': -125,
#   'changeRate': -0.99,
#   'nav': None,
#   'threeMonthEarnRate': -2.1966,
#   'quant': 218169,
#   'amonut': 2743,
#   'marketSum': 2463},
#  {'itemcode': '275980',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 글로벌4차산업혁신기술(합성 H)',
#   'nowVal': 18030,
#   'risefall': '2',
#   'changeVal': 205,
#   'changeRate': 1.15,
#   'nav': None,
#   'threeMonthEarnRate': 24.6939,
#   'quant': 146328,
#   'amonut': 2627,
#   'marketSum': 2452},
#  {'itemcode': '148070',
#   'etfTabCode': 6,
#   'itemname': 'KOSEF 국고채10년',
#   'nowVal': 122485,
#   'risefall': '5',
#   'changeVal': -50,
#   'changeRate': -0.04,
#   'nav': 122467.0,
#   'threeMonthEarnRate': -0.7252,
#   'quant': 6511,
#   'amonut': 797,
#   'marketSum': 2450},
#  {'itemcode': '290130',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR ESG사회책임투자',
#   'nowVal': 14340,
#   'risefall': '2',
#   'changeVal': 175,
#   'changeRate': 1.24,
#   'nav': 14336.0,
#   'threeMonthEarnRate': 44.3934,
#   'quant': 691445,
#   'amonut': 9881,
#   'marketSum': 2330},
#  {'itemcode': '168580',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 중국본토CSI300',
#   'nowVal': 33380,
#   'risefall': '2',
#   'changeVal': 185,
#   'changeRate': 0.56,
#   'nav': None,
#   'threeMonthEarnRate': 17.7545,
#   'quant': 13784,
#   'amonut': 459,
#   'marketSum': 2170},
#  {'itemcode': '091170',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 은행',
#   'nowVal': 6110,
#   'risefall': '5',
#   'changeVal': -25,
#   'changeRate': -0.41,
#   'nav': 6145.0,
#   'threeMonthEarnRate': 6.8815,
#   'quant': 506740,
#   'amonut': 3114,
#   'marketSum': 2145},
#  {'itemcode': '278240',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 코스닥150선물레버리지',
#   'nowVal': 16290,
#   'risefall': '2',
#   'changeVal': 80,
#   'changeRate': 0.49,
#   'nav': 16279.0,
#   'threeMonthEarnRate': 48.9889,
#   'quant': 138450,
#   'amonut': 2230,
#   'marketSum': 2110},
#  {'itemcode': '306540',
#   'etfTabCode': 6,
#   'itemname': 'HANARO 단기통안채',
#   'nowVal': 102920,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 102931.0,
#   'threeMonthEarnRate': 0.1118,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 2047},
#  {'itemcode': '245710',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 베트남VN30(합성)',
#   'nowVal': 15590,
#   'risefall': '2',
#   'changeVal': 540,
#   'changeRate': 3.59,
#   'nav': None,
#   'threeMonthEarnRate': 17.3489,
#   'quant': 309226,
#   'amonut': 4773,
#   'marketSum': 2042},
#  {'itemcode': '367770',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR Fn수소경제테마',
#   'nowVal': 13840,
#   'risefall': '2',
#   'changeVal': 270,
#   'changeRate': 1.99,
#   'nav': 13838.0,
#   'threeMonthEarnRate': 36.3134,
#   'quant': 1423245,
#   'amonut': 19644,
#   'marketSum': 1861},
#  {'itemcode': '328370',
#   'etfTabCode': 1,
#   'itemname': 'ARIRANG 코스피TR',
#   'nowVal': 15680,
#   'risefall': '2',
#   'changeVal': 240,
#   'changeRate': 1.55,
#   'nav': 15679.0,
#   'threeMonthEarnRate': 37.0008,
#   'quant': 15674,
#   'amonut': 243,
#   'marketSum': 1850},
#  {'itemcode': '302450',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 코스피',
#   'nowVal': 32020,
#   'risefall': '2',
#   'changeVal': 340,
#   'changeRate': 1.07,
#   'nav': 32013.0,
#   'threeMonthEarnRate': 37.5895,
#   'quant': 82,
#   'amonut': 2,
#   'marketSum': 1841},
#  {'itemcode': '270810',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 코스닥150',
#   'nowVal': 14845,
#   'risefall': '2',
#   'changeVal': 100,
#   'changeRate': 0.68,
#   'nav': 14951.0,
#   'threeMonthEarnRate': 21.2582,
#   'quant': 14403,
#   'amonut': 211,
#   'marketSum': 1820},
#  {'itemcode': '332930',
#   'etfTabCode': 1,
#   'itemname': 'HANARO 200TR',
#   'nowVal': 50535,
#   'risefall': '2',
#   'changeVal': 570,
#   'changeRate': 1.14,
#   'nav': 50579.0,
#   'threeMonthEarnRate': 39.8796,
#   'quant': 3837,
#   'amonut': 193,
#   'marketSum': 1693},
#  {'itemcode': '325020',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 배당가치',
#   'nowVal': 12825,
#   'risefall': '2',
#   'changeVal': 150,
#   'changeRate': 1.18,
#   'nav': 12815.0,
#   'threeMonthEarnRate': 28.2245,
#   'quant': 142218,
#   'amonut': 1810,
#   'marketSum': 1693},
#  {'itemcode': '150460',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 중국소비테마',
#   'nowVal': 7915,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.13,
#   'nav': 7915.0,
#   'threeMonthEarnRate': 20.8715,
#   'quant': 73948,
#   'amonut': 582,
#   'marketSum': 1691},
#  {'itemcode': '204480',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나CSI300레버리지(합성)',
#   'nowVal': 36810,
#   'risefall': '2',
#   'changeVal': 210,
#   'changeRate': 0.57,
#   'nav': None,
#   'threeMonthEarnRate': 43.9244,
#   'quant': 420860,
#   'amonut': 15479,
#   'marketSum': 1620},
#  {'itemcode': '272580',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 단기채권액티브',
#   'nowVal': 50040,
#   'risefall': '2',
#   'changeVal': 5,
#   'changeRate': 0.01,
#   'nav': 50036.0,
#   'threeMonthEarnRate': 0.1,
#   'quant': 2799,
#   'amonut': 140,
#   'marketSum': 1605},
#  {'itemcode': '161510',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG 고배당주',
#   'nowVal': 10560,
#   'risefall': '2',
#   'changeVal': 35,
#   'changeRate': 0.33,
#   'nav': 10607.0,
#   'threeMonthEarnRate': 11.1991,
#   'quant': 46658,
#   'amonut': 492,
#   'marketSum': 1603},
#  {'itemcode': '091160',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 반도체',
#   'nowVal': 36065,
#   'risefall': '2',
#   'changeVal': 95,
#   'changeRate': 0.26,
#   'nav': 36203.0,
#   'threeMonthEarnRate': 43.9087,
#   'quant': 292684,
#   'amonut': 10521,
#   'marketSum': 1497},
#  {'itemcode': '196230',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 단기통안채',
#   'nowVal': 104265,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.01,
#   'nav': 104264.0,
#   'threeMonthEarnRate': 0.1537,
#   'quant': 1282477,
#   'amonut': 133711,
#   'marketSum': 1487},
#  {'itemcode': '143860',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 헬스케어',
#   'nowVal': 49890,
#   'risefall': '5',
#   'changeVal': -445,
#   'changeRate': -0.88,
#   'nav': 50147.0,
#   'threeMonthEarnRate': 20.6206,
#   'quant': 67025,
#   'amonut': 3325,
#   'marketSum': 1407},
#  {'itemcode': '143850',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국S&P500선물(H)',
#   'nowVal': 44725,
#   'risefall': '2',
#   'changeVal': 595,
#   'changeRate': 1.35,
#   'nav': None,
#   'threeMonthEarnRate': 15.8723,
#   'quant': 55436,
#   'amonut': 2476,
#   'marketSum': 1398},
#  {'itemcode': '144600',
#   'etfTabCode': 5,
#   'itemname': 'KODEX 은선물(H)',
#   'nowVal': 5570,
#   'risefall': '5',
#   'changeVal': -415,
#   'changeRate': -6.93,
#   'nav': None,
#   'threeMonthEarnRate': 19.1044,
#   'quant': 3489736,
#   'amonut': 19557,
#   'marketSum': 1387},
#  {'itemcode': '190620',
#   'etfTabCode': 6,
#   'itemname': 'KINDEX 단기통안채',
#   'nowVal': 100155,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 100158.0,
#   'threeMonthEarnRate': 0.1239,
#   'quant': 591,
#   'amonut': 59,
#   'marketSum': 1382},
#  {'itemcode': '267770',
#   'etfTabCode': 3,
#   'itemname': 'TIGER 200선물레버리지',
#   'nowVal': 20835,
#   'risefall': '2',
#   'changeVal': 335,
#   'changeRate': 1.63,
#   'nav': 20890.0,
#   'threeMonthEarnRate': 91.4098,
#   'quant': 2167499,
#   'amonut': 44714,
#   'marketSum': 1354},
#  {'itemcode': '360750',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국S&P500',
#   'nowVal': 10785,
#   'risefall': '2',
#   'changeVal': 125,
#   'changeRate': 1.17,
#   'nav': None,
#   'threeMonthEarnRate': 14.0961,
#   'quant': 196555,
#   'amonut': 2117,
#   'marketSum': 1337},
#  {'itemcode': '139280',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 경기방어',
#   'nowVal': 12900,
#   'risefall': '5',
#   'changeVal': -55,
#   'changeRate': -0.42,
#   'nav': 12902.0,
#   'threeMonthEarnRate': 19.7873,
#   'quant': 35099,
#   'amonut': 449,
#   'marketSum': 1269},
#  {'itemcode': '325010',
#   'etfTabCode': 2,
#   'itemname': 'KODEX Fn성장',
#   'nowVal': 19195,
#   'risefall': '2',
#   'changeVal': 145,
#   'changeRate': 0.76,
#   'nav': 19170.0,
#   'threeMonthEarnRate': 41.0066,
#   'quant': 4240,
#   'amonut': 80,
#   'marketSum': 1267},
#  {'itemcode': '138540',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 현대차그룹+펀더멘털',
#   'nowVal': 28115,
#   'risefall': '2',
#   'changeVal': 1110,
#   'changeRate': 4.11,
#   'nav': 28138.0,
#   'threeMonthEarnRate': 48.8699,
#   'quant': 328104,
#   'amonut': 9256,
#   'marketSum': 1243},
#  {'itemcode': '360200',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 미국S&P500',
#   'nowVal': 10860,
#   'risefall': '2',
#   'changeVal': 125,
#   'changeRate': 1.16,
#   'nav': None,
#   'threeMonthEarnRate': 14.0322,
#   'quant': 116912,
#   'amonut': 1267,
#   'marketSum': 1205},
#  {'itemcode': '367380',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 미국나스닥100',
#   'nowVal': 11620,
#   'risefall': '2',
#   'changeVal': 180,
#   'changeRate': 1.57,
#   'nav': None,
#   'threeMonthEarnRate': 18.2795,
#   'quant': 131991,
#   'amonut': 1527,
#   'marketSum': 1197},
#  {'itemcode': '273140',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 단기변동금리부채권액티브',
#   'nowVal': 102415,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.01,
#   'nav': 102412.0,
#   'threeMonthEarnRate': 0.1515,
#   'quant': 960,
#   'amonut': 98,
#   'marketSum': 1169},
#  {'itemcode': '233160',
#   'etfTabCode': 1,
#   'itemname': 'TIGER 코스닥150 레버리지',
#   'nowVal': 17175,
#   'risefall': '2',
#   'changeVal': 105,
#   'changeRate': 0.62,
#   'nav': 17307.0,
#   'threeMonthEarnRate': 47.6005,
#   'quant': 256576,
#   'amonut': 4350,
#   'marketSum': 1142},
#  {'itemcode': '176950',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 국채선물10년인버스',
#   'nowVal': 46335,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.05,
#   'nav': 46350.0,
#   'threeMonthEarnRate': 1.1356,
#   'quant': 222,
#   'amonut': 10,
#   'marketSum': 1134},
#  {'itemcode': '252710',
#   'etfTabCode': 3,
#   'itemname': 'TIGER 200선물인버스2X',
#   'nowVal': 2125,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -1.62,
#   'nav': 2123.0,
#   'threeMonthEarnRate': -51.2416,
#   'quant': 5765820,
#   'amonut': 12333,
#   'marketSum': 1120},
#  {'itemcode': '130680',
#   'etfTabCode': 5,
#   'itemname': 'TIGER 원유선물Enhanced(H)',
#   'nowVal': 2470,
#   'risefall': '2',
#   'changeVal': 30,
#   'changeRate': 1.23,
#   'nav': None,
#   'threeMonthEarnRate': 39.828,
#   'quant': 884160,
#   'amonut': 2189,
#   'marketSum': 1091},
#  {'itemcode': '219480',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국S&P500선물(H)',
#   'nowVal': 18380,
#   'risefall': '2',
#   'changeVal': 235,
#   'changeRate': 1.3,
#   'nav': None,
#   'threeMonthEarnRate': 15.7575,
#   'quant': 59547,
#   'amonut': 1093,
#   'marketSum': 1084},
#  {'itemcode': '108450',
#   'etfTabCode': 2,
#   'itemname': 'KINDEX 삼성그룹섹터가중',
#   'nowVal': 16910,
#   'risefall': '5',
#   'changeVal': -5,
#   'changeRate': -0.03,
#   'nav': 16984.0,
#   'threeMonthEarnRate': 39.6203,
#   'quant': 4275,
#   'amonut': 71,
#   'marketSum': 1082},
#  {'itemcode': '156080',
#   'etfTabCode': 1,
#   'itemname': 'KODEX MSCI Korea',
#   'nowVal': 20585,
#   'risefall': '2',
#   'changeVal': 50,
#   'changeRate': 0.24,
#   'nav': 20715.0,
#   'threeMonthEarnRate': 41.0855,
#   'quant': 195,
#   'amonut': 4,
#   'marketSum': 1029},
#  {'itemcode': '282000',
#   'etfTabCode': 3,
#   'itemname': 'KBSTAR 국고채3년선물인버스',
#   'nowVal': 99425,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.02,
#   'nav': 99422.0,
#   'threeMonthEarnRate': -0.0252,
#   'quant': 13,
#   'amonut': 1,
#   'marketSum': 1026},
#  {'itemcode': '368190',
#   'etfTabCode': 2,
#   'itemname': 'HANARO Fn K-뉴딜디지털플러스',
#   'nowVal': 13750,
#   'risefall': '2',
#   'changeVal': 125,
#   'changeRate': 0.92,
#   'nav': 13801.0,
#   'threeMonthEarnRate': None,
#   'quant': 472127,
#   'amonut': 6458,
#   'marketSum': 1024},
#  {'itemcode': '371160',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나항셍테크',
#   'nowVal': 12585,
#   'risefall': '2',
#   'changeVal': 70,
#   'changeRate': 0.56,
#   'nav': None,
#   'threeMonthEarnRate': None,
#   'quant': 565970,
#   'amonut': 7104,
#   'marketSum': 1007},
#  {'itemcode': '367760',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR Fn5G테크',
#   'nowVal': 12315,
#   'risefall': '2',
#   'changeVal': 75,
#   'changeRate': 0.61,
#   'nav': 12331.0,
#   'threeMonthEarnRate': 24.5167,
#   'quant': 127617,
#   'amonut': 1568,
#   'marketSum': 985},
#  {'itemcode': '091230',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 반도체',
#   'nowVal': 37090,
#   'risefall': '2',
#   'changeVal': 220,
#   'changeRate': 0.6,
#   'nav': 37077.0,
#   'threeMonthEarnRate': 43.2679,
#   'quant': 71687,
#   'amonut': 2638,
#   'marketSum': 979},
#  {'itemcode': '283580',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 중국본토CSI300',
#   'nowVal': 15015,
#   'risefall': '2',
#   'changeVal': 40,
#   'changeRate': 0.27,
#   'nav': None,
#   'threeMonthEarnRate': 17.2211,
#   'quant': 42542,
#   'amonut': 638,
#   'marketSum': 961},
#  {'itemcode': '315960',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 대형고배당10TR',
#   'nowVal': 16730,
#   'risefall': '2',
#   'changeVal': 195,
#   'changeRate': 1.18,
#   'nav': 16716.0,
#   'threeMonthEarnRate': 39.5358,
#   'quant': 4489,
#   'amonut': 75,
#   'marketSum': 954},
#  {'itemcode': '225040',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국S&P500레버리지(합성 H)',
#   'nowVal': 25580,
#   'risefall': '2',
#   'changeVal': 705,
#   'changeRate': 2.83,
#   'nav': None,
#   'threeMonthEarnRate': 32.8792,
#   'quant': 20028,
#   'amonut': 510,
#   'marketSum': 946},
#  {'itemcode': '114260',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 국고채3년',
#   'nowVal': 58140,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.03,
#   'nav': 58161.0,
#   'threeMonthEarnRate': 0.1464,
#   'quant': 14536,
#   'amonut': 845,
#   'marketSum': 942},
#  {'itemcode': '302190',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 중장기국채',
#   'nowVal': 52795,
#   'risefall': '2',
#   'changeVal': 30,
#   'changeRate': 0.06,
#   'nav': 52777.0,
#   'threeMonthEarnRate': -0.3852,
#   'quant': 3596,
#   'amonut': 189,
#   'marketSum': 898},
#  {'itemcode': '292190',
#   'etfTabCode': 1,
#   'itemname': 'KODEX KRX300',
#   'nowVal': 19940,
#   'risefall': '2',
#   'changeVal': 185,
#   'changeRate': 0.94,
#   'nav': 19949.0,
#   'threeMonthEarnRate': 38.2435,
#   'quant': 70633,
#   'amonut': 1402,
#   'marketSum': 857},
#  {'itemcode': '195930',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 유로스탁스50(합성 H)',
#   'nowVal': 12120,
#   'risefall': '2',
#   'changeVal': 245,
#   'changeRate': 2.06,
#   'nav': None,
#   'threeMonthEarnRate': 19.2269,
#   'quant': 17732,
#   'amonut': 214,
#   'marketSum': 848},
#  {'itemcode': '364970',
#   'etfTabCode': 2,
#   'itemname': 'TIGER KRX바이오K-뉴딜',
#   'nowVal': 12160,
#   'risefall': '5',
#   'changeVal': -105,
#   'changeRate': -0.86,
#   'nav': 12165.0,
#   'threeMonthEarnRate': 22.1005,
#   'quant': 312086,
#   'amonut': 3777,
#   'marketSum': 845},
#  {'itemcode': '272560',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 단기국공채액티브',
#   'nowVal': 101795,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.01,
#   'nav': 101791.0,
#   'threeMonthEarnRate': 0.2462,
#   'quant': 1152,
#   'amonut': 117,
#   'marketSum': 799},
#  {'itemcode': '245360',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나HSCEI',
#   'nowVal': 13495,
#   'risefall': '5',
#   'changeVal': -100,
#   'changeRate': -0.74,
#   'nav': None,
#   'threeMonthEarnRate': 14.7257,
#   'quant': 22548,
#   'amonut': 303,
#   'marketSum': 783},
#  {'itemcode': '102970',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 증권',
#   'nowVal': 7915,
#   'risefall': '2',
#   'changeVal': 60,
#   'changeRate': 0.76,
#   'nav': 7911.0,
#   'threeMonthEarnRate': 24.8807,
#   'quant': 140449,
#   'amonut': 1110,
#   'marketSum': 712},
#  {'itemcode': '195980',
#   'etfTabCode': 4,
#   'itemname': 'ARIRANG 신흥국MSCI(합성 H)',
#   'nowVal': 13410,
#   'risefall': '2',
#   'changeVal': 95,
#   'changeRate': 0.71,
#   'nav': None,
#   'threeMonthEarnRate': 23.9181,
#   'quant': 45635,
#   'amonut': 609,
#   'marketSum': 705},
#  {'itemcode': '292500',
#   'etfTabCode': 1,
#   'itemname': 'SMART KRX300',
#   'nowVal': 19880,
#   'risefall': '2',
#   'changeVal': 125,
#   'changeRate': 0.63,
#   'nav': 19922.0,
#   'threeMonthEarnRate': 38.8752,
#   'quant': 9503,
#   'amonut': 188,
#   'marketSum': 696},
#  {'itemcode': '261240',
#   'etfTabCode': 7,
#   'itemname': 'KODEX 미국달러선물',
#   'nowVal': 9880,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.1,
#   'nav': 9882.0,
#   'threeMonthEarnRate': -1.3959,
#   'quant': 169488,
#   'amonut': 1673,
#   'marketSum': 684},
#  {'itemcode': '372330',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 차이나항셍테크',
#   'nowVal': 12610,
#   'risefall': '2',
#   'changeVal': 55,
#   'changeRate': 0.44,
#   'nav': None,
#   'threeMonthEarnRate': None,
#   'quant': 610555,
#   'amonut': 7688,
#   'marketSum': 668},
#  {'itemcode': '256750',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 심천ChiNext(합성)',
#   'nowVal': 14135,
#   'risefall': '2',
#   'changeVal': 155,
#   'changeRate': 1.11,
#   'nav': None,
#   'threeMonthEarnRate': 22.0427,
#   'quant': 96199,
#   'amonut': 1362,
#   'marketSum': 664},
#  {'itemcode': '182480',
#   'etfTabCode': 7,
#   'itemname': 'TIGER 미국MSCI리츠(합성 H)',
#   'nowVal': 12435,
#   'risefall': '2',
#   'changeVal': 65,
#   'changeRate': 0.53,
#   'nav': None,
#   'threeMonthEarnRate': 16.1066,
#   'quant': 15436,
#   'amonut': 192,
#   'marketSum': 659},
#  {'itemcode': '371470',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나바이오테크SOLACTIVE',
#   'nowVal': 13280,
#   'risefall': '2',
#   'changeVal': 185,
#   'changeRate': 1.41,
#   'nav': None,
#   'threeMonthEarnRate': None,
#   'quant': 263913,
#   'amonut': 3477,
#   'marketSum': 659},
#  {'itemcode': '310960',
#   'etfTabCode': 1,
#   'itemname': 'TIGER 200TR',
#   'nowVal': 22615,
#   'risefall': '2',
#   'changeVal': 185,
#   'changeRate': 0.82,
#   'nav': 22667.0,
#   'threeMonthEarnRate': 40.0561,
#   'quant': 1505,
#   'amonut': 33,
#   'marketSum': 656},
#  {'itemcode': '277630',
#   'etfTabCode': 1,
#   'itemname': 'TIGER 코스피',
#   'nowVal': 31770,
#   'risefall': '2',
#   'changeVal': 325,
#   'changeRate': 1.03,
#   'nav': 31888.0,
#   'threeMonthEarnRate': 36.9436,
#   'quant': 4759,
#   'amonut': 150,
#   'marketSum': 651},
#  {'itemcode': '114820',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 국채3년',
#   'nowVal': 111300,
#   'risefall': '2',
#   'changeVal': 55,
#   'changeRate': 0.05,
#   'nav': 111305.0,
#   'threeMonthEarnRate': 0.2297,
#   'quant': 499,
#   'amonut': 55,
#   'marketSum': 634},
#  {'itemcode': '336160',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 금융채액티브',
#   'nowVal': 103450,
#   'risefall': '2',
#   'changeVal': 80,
#   'changeRate': 0.08,
#   'nav': 103420.0,
#   'threeMonthEarnRate': 0.5789,
#   'quant': 11,
#   'amonut': 1,
#   'marketSum': 631},
#  {'itemcode': '363580',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 200IT TR',
#   'nowVal': 15300,
#   'risefall': '2',
#   'changeVal': 125,
#   'changeRate': 0.82,
#   'nav': 15341.0,
#   'threeMonthEarnRate': 58.8173,
#   'quant': 6502,
#   'amonut': 99,
#   'marketSum': 627},
#  {'itemcode': '157490',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 소프트웨어',
#   'nowVal': 16950,
#   'risefall': '2',
#   'changeVal': 445,
#   'changeRate': 2.7,
#   'nav': 16975.0,
#   'threeMonthEarnRate': 25.561,
#   'quant': 227965,
#   'amonut': 3832,
#   'marketSum': 627},
#  {'itemcode': '326240',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR IT플러스',
#   'nowVal': 21925,
#   'risefall': '2',
#   'changeVal': 230,
#   'changeRate': 1.06,
#   'nav': 21995.0,
#   'threeMonthEarnRate': 42.2622,
#   'quant': 182470,
#   'amonut': 3983,
#   'marketSum': 627},
#  {'itemcode': '219390',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국S&P원유생산기업(합성 H)',
#   'nowVal': 3005,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': None,
#   'threeMonthEarnRate': 59.8404,
#   'quant': 223531,
#   'amonut': 670,
#   'marketSum': 624},
#  {'itemcode': '329200',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 부동산인프라고배당',
#   'nowVal': 4980,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.3,
#   'nav': 5006.0,
#   'threeMonthEarnRate': 6.8661,
#   'quant': 77959,
#   'amonut': 387,
#   'marketSum': 618},
#  {'itemcode': '289260',
#   'etfTabCode': 2,
#   'itemname': 'TIGER MSCI KOREA ESG리더스',
#   'nowVal': 12390,
#   'risefall': '2',
#   'changeVal': 150,
#   'changeRate': 1.23,
#   'nav': 12402.0,
#   'threeMonthEarnRate': 41.5028,
#   'quant': 12131,
#   'amonut': 149,
#   'marketSum': 610},
#  {'itemcode': '243880',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200IT레버리지',
#   'nowVal': 75190,
#   'risefall': '2',
#   'changeVal': 990,
#   'changeRate': 1.33,
#   'nav': 75796.0,
#   'threeMonthEarnRate': 147.3333,
#   'quant': 28875,
#   'amonut': 2160,
#   'marketSum': 602},
#  {'itemcode': '298770',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 한국대만IT프리미어',
#   'nowVal': 20050,
#   'risefall': '2',
#   'changeVal': 65,
#   'changeRate': 0.33,
#   'nav': None,
#   'threeMonthEarnRate': 42.2419,
#   'quant': 224856,
#   'amonut': 4510,
#   'marketSum': 602},
#  {'itemcode': '266360',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 미디어&엔터테인먼트',
#   'nowVal': 22170,
#   'risefall': '2',
#   'changeVal': 480,
#   'changeRate': 2.21,
#   'nav': 22169.0,
#   'threeMonthEarnRate': 24.7268,
#   'quant': 51358,
#   'amonut': 1126,
#   'marketSum': 599},
#  {'itemcode': '136340',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 중기우량회사채',
#   'nowVal': 105520,
#   'risefall': '2',
#   'changeVal': 20,
#   'changeRate': 0.02,
#   'nav': 105492.0,
#   'threeMonthEarnRate': 0.9501,
#   'quant': 1381,
#   'amonut': 145,
#   'marketSum': 591},
#  {'itemcode': '266370',
#   'etfTabCode': 2,
#   'itemname': 'KODEX IT',
#   'nowVal': 22290,
#   'risefall': '2',
#   'changeVal': 270,
#   'changeRate': 1.23,
#   'nav': 22284.0,
#   'threeMonthEarnRate': 50.5126,
#   'quant': 33465,
#   'amonut': 742,
#   'marketSum': 580},
#  {'itemcode': '304780',
#   'etfTabCode': 1,
#   'itemname': 'HANARO 200선물레버리지',
#   'nowVal': 30260,
#   'risefall': '2',
#   'changeVal': 475,
#   'changeRate': 1.59,
#   'nav': 30346.0,
#   'threeMonthEarnRate': 91.9755,
#   'quant': 3493,
#   'amonut': 103,
#   'marketSum': 575},
#  {'itemcode': '123310',
#   'etfTabCode': 3,
#   'itemname': 'TIGER 인버스',
#   'nowVal': 4255,
#   'risefall': '5',
#   'changeVal': -40,
#   'changeRate': -0.93,
#   'nav': 4263.0,
#   'threeMonthEarnRate': -29.5902,
#   'quant': 777440,
#   'amonut': 3322,
#   'marketSum': 570},
#  {'itemcode': '337140',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 코스피대형주',
#   'nowVal': 15185,
#   'risefall': '2',
#   'changeVal': 90,
#   'changeRate': 0.6,
#   'nav': 15247.0,
#   'threeMonthEarnRate': 39.5101,
#   'quant': 1472,
#   'amonut': 22,
#   'marketSum': 547},
#  {'itemcode': '174360',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 중국본토대형주CSI100',
#   'nowVal': 23580,
#   'risefall': '2',
#   'changeVal': 70,
#   'changeRate': 0.3,
#   'nav': None,
#   'threeMonthEarnRate': 18.6175,
#   'quant': 62430,
#   'amonut': 1463,
#   'marketSum': 542},
#  {'itemcode': '137610',
#   'etfTabCode': 5,
#   'itemname': 'TIGER 농산물선물Enhanced(H)',
#   'nowVal': 5560,
#   'risefall': '5',
#   'changeVal': -55,
#   'changeRate': -0.98,
#   'nav': None,
#   'threeMonthEarnRate': 22.7322,
#   'quant': 63030,
#   'amonut': 350,
#   'marketSum': 500},
#  {'itemcode': '130730',
#   'etfTabCode': 6,
#   'itemname': 'KOSEF 단기자금',
#   'nowVal': 100905,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.01,
#   'nav': 100906.0,
#   'threeMonthEarnRate': 0.1429,
#   'quant': 237193,
#   'amonut': 23933,
#   'marketSum': 485},
#  {'itemcode': '122260',
#   'etfTabCode': 6,
#   'itemname': 'KOSEF 통안채1년',
#   'nowVal': 101120,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.01,
#   'nav': 101115.0,
#   'threeMonthEarnRate': 0.2508,
#   'quant': 546820,
#   'amonut': 55286,
#   'marketSum': 475},
#  {'itemcode': '305080',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 미국채10년선물',
#   'nowVal': 11655,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -0.3,
#   'nav': None,
#   'threeMonthEarnRate': -2.38,
#   'quant': 44710,
#   'amonut': 520,
#   'marketSum': 466},
#  {'itemcode': '292050',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR KRX300',
#   'nowVal': 20105,
#   'risefall': '2',
#   'changeVal': 210,
#   'changeRate': 1.06,
#   'nav': 20102.0,
#   'threeMonthEarnRate': 38.4963,
#   'quant': 10624,
#   'amonut': 212,
#   'marketSum': 462},
#  {'itemcode': '365000',
#   'etfTabCode': 2,
#   'itemname': 'TIGER KRX인터넷K-뉴딜',
#   'nowVal': 11515,
#   'risefall': '2',
#   'changeVal': 235,
#   'changeRate': 2.08,
#   'nav': 11583.0,
#   'threeMonthEarnRate': 18.8619,
#   'quant': 129331,
#   'amonut': 1477,
#   'marketSum': 461},
#  {'itemcode': '245340',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국다우존스30',
#   'nowVal': 17225,
#   'risefall': '2',
#   'changeVal': 220,
#   'changeRate': 1.29,
#   'nav': None,
#   'threeMonthEarnRate': 12.8925,
#   'quant': 20446,
#   'amonut': 351,
#   'marketSum': 448},
#  {'itemcode': '117700',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 건설',
#   'nowVal': 3230,
#   'risefall': '2',
#   'changeVal': 110,
#   'changeRate': 3.53,
#   'nav': 3229.0,
#   'threeMonthEarnRate': 36.8421,
#   'quant': 775675,
#   'amonut': 2465,
#   'marketSum': 439},
#  {'itemcode': '359210',
#   'etfTabCode': 1,
#   'itemname': 'KODEX 코스피TR',
#   'nowVal': 14395,
#   'risefall': '2',
#   'changeVal': 75,
#   'changeRate': 0.52,
#   'nav': 14489.0,
#   'threeMonthEarnRate': 36.837,
#   'quant': 93,
#   'amonut': 1,
#   'marketSum': 432},
#  {'itemcode': '368590',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국나스닥100',
#   'nowVal': 11255,
#   'risefall': '2',
#   'changeVal': 170,
#   'changeRate': 1.53,
#   'nav': None,
#   'threeMonthEarnRate': None,
#   'quant': 775478,
#   'amonut': 8708,
#   'marketSum': 428},
#  {'itemcode': '272570',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 중장기국공채액티브',
#   'nowVal': 104305,
#   'risefall': '2',
#   'changeVal': 40,
#   'changeRate': 0.04,
#   'nav': 104285.0,
#   'threeMonthEarnRate': 0.3416,
#   'quant': 142,
#   'amonut': 14,
#   'marketSum': 417},
#  {'itemcode': '364990',
#   'etfTabCode': 2,
#   'itemname': 'TIGER KRX게임K-뉴딜',
#   'nowVal': 12510,
#   'risefall': '2',
#   'changeVal': 180,
#   'changeRate': 1.46,
#   'nav': 12540.0,
#   'threeMonthEarnRate': 32.3671,
#   'quant': 120199,
#   'amonut': 1491,
#   'marketSum': 413},
#  {'itemcode': '356540',
#   'etfTabCode': 6,
#   'itemname': 'KINDEX KIS종합채권(AA-이상)액티브',
#   'nowVal': 99200,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 99218.0,
#   'threeMonthEarnRate': -0.5913,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 397},
#  {'itemcode': '139250',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 에너지화학',
#   'nowVal': 22715,
#   'risefall': '2',
#   'changeVal': 255,
#   'changeRate': 1.14,
#   'nav': 22726.0,
#   'threeMonthEarnRate': 61.3505,
#   'quant': 24617,
#   'amonut': 555,
#   'marketSum': 391},
#  {'itemcode': '304770',
#   'etfTabCode': 1,
#   'itemname': 'HANARO 코스닥150',
#   'nowVal': 14980,
#   'risefall': '2',
#   'changeVal': 55,
#   'changeRate': 0.37,
#   'nav': 15065.0,
#   'threeMonthEarnRate': 22.4364,
#   'quant': 1252,
#   'amonut': 18,
#   'marketSum': 377},
#  {'itemcode': '228810',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 미디어컨텐츠',
#   'nowVal': 6845,
#   'risefall': '2',
#   'changeVal': 105,
#   'changeRate': 1.56,
#   'nav': 6841.0,
#   'threeMonthEarnRate': 30.2415,
#   'quant': 206947,
#   'amonut': 1407,
#   'marketSum': 376},
#  {'itemcode': '371450',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 글로벌클라우드컴퓨팅INDXX',
#   'nowVal': 11410,
#   'risefall': '2',
#   'changeVal': 180,
#   'changeRate': 1.6,
#   'nav': None,
#   'threeMonthEarnRate': None,
#   'quant': 126931,
#   'amonut': 1446,
#   'marketSum': 374},
#  {'itemcode': '169950',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 중국본토 A50',
#   'nowVal': 24840,
#   'risefall': '2',
#   'changeVal': 180,
#   'changeRate': 0.73,
#   'nav': None,
#   'threeMonthEarnRate': 18.7861,
#   'quant': 20830,
#   'amonut': 514,
#   'marketSum': 373},
#  {'itemcode': '363570',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 장기종합채권(AA-이상)액티브KAP',
#   'nowVal': 98050,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 98056.0,
#   'threeMonthEarnRate': -1.2787,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 371},
#  {'itemcode': '099140',
#   'etfTabCode': 4,
#   'itemname': 'KODEX China H',
#   'nowVal': 23075,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.11,
#   'nav': None,
#   'threeMonthEarnRate': 14.4204,
#   'quant': 7684,
#   'amonut': 176,
#   'marketSum': 369},
#  {'itemcode': '306520',
#   'etfTabCode': 3,
#   'itemname': 'HANARO 200선물인버스',
#   'nowVal': 8865,
#   'risefall': '5',
#   'changeVal': -80,
#   'changeRate': -0.89,
#   'nav': 8868.0,
#   'threeMonthEarnRate': -29.5947,
#   'quant': 18621,
#   'amonut': 165,
#   'marketSum': 368},
#  {'itemcode': '304940',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국나스닥100선물(H)',
#   'nowVal': 17245,
#   'risefall': '2',
#   'changeVal': 300,
#   'changeRate': 1.77,
#   'nav': None,
#   'threeMonthEarnRate': 19.9221,
#   'quant': 52765,
#   'amonut': 907,
#   'marketSum': 354},
#  {'itemcode': '329750',
#   'etfTabCode': 6,
#   'itemname': 'TIGER 미국달러단기채권액티브',
#   'nowVal': 9555,
#   'risefall': '5',
#   'changeVal': -15,
#   'changeRate': -0.16,
#   'nav': None,
#   'threeMonthEarnRate': -1.4926,
#   'quant': 101042,
#   'amonut': 964,
#   'marketSum': 353},
#  {'itemcode': '280930',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국러셀2000(H)',
#   'nowVal': 13985,
#   'risefall': '2',
#   'changeVal': 85,
#   'changeRate': 0.61,
#   'nav': None,
#   'threeMonthEarnRate': 38.0337,
#   'quant': 34927,
#   'amonut': 487,
#   'marketSum': 350},
#  {'itemcode': '114100',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 국고채3년',
#   'nowVal': 113565,
#   'risefall': '5',
#   'changeVal': -5,
#   'changeRate': 0.0,
#   'nav': 113569.0,
#   'threeMonthEarnRate': 0.3179,
#   'quant': 1026,
#   'amonut': 116,
#   'marketSum': 341},
#  {'itemcode': '261250',
#   'etfTabCode': 7,
#   'itemname': 'KODEX 미국달러선물레버리지',
#   'nowVal': 9035,
#   'risefall': '5',
#   'changeVal': -20,
#   'changeRate': -0.22,
#   'nav': 9032.0,
#   'threeMonthEarnRate': -2.8955,
#   'quant': 59849,
#   'amonut': 539,
#   'marketSum': 341},
#  {'itemcode': '114470',
#   'etfTabCode': 6,
#   'itemname': 'KOSEF 국고채3년',
#   'nowVal': 112975,
#   'risefall': '2',
#   'changeVal': 60,
#   'changeRate': 0.05,
#   'nav': 112982.0,
#   'threeMonthEarnRate': 0.1729,
#   'quant': 253,
#   'amonut': 28,
#   'marketSum': 339},
#  {'itemcode': '292160',
#   'etfTabCode': 1,
#   'itemname': 'TIGER KRX300',
#   'nowVal': 19860,
#   'risefall': '2',
#   'changeVal': 180,
#   'changeRate': 0.91,
#   'nav': 19862.0,
#   'threeMonthEarnRate': 38.7968,
#   'quant': 430,
#   'amonut': 8,
#   'marketSum': 338},
#  {'itemcode': '204450',
#   'etfTabCode': 4,
#   'itemname': 'KODEX China H 레버리지(H)',
#   'nowVal': 8195,
#   'risefall': '5',
#   'changeVal': -15,
#   'changeRate': -0.18,
#   'nav': None,
#   'threeMonthEarnRate': 35.7024,
#   'quant': 34159,
#   'amonut': 277,
#   'marketSum': 336},
#  {'itemcode': '289040',
#   'etfTabCode': 2,
#   'itemname': 'KODEX MSCI KOREA ESG유니버설',
#   'nowVal': 12860,
#   'risefall': '2',
#   'changeVal': 115,
#   'changeRate': 0.9,
#   'nav': 12926.0,
#   'threeMonthEarnRate': 38.4573,
#   'quant': 3530,
#   'amonut': 45,
#   'marketSum': 334},
#  {'itemcode': '252400',
#   'etfTabCode': 3,
#   'itemname': 'KBSTAR 200선물레버리지',
#   'nowVal': 25315,
#   'risefall': '2',
#   'changeVal': 425,
#   'changeRate': 1.71,
#   'nav': 25347.0,
#   'threeMonthEarnRate': 92.1265,
#   'quant': 42158,
#   'amonut': 1061,
#   'marketSum': 329},
#  {'itemcode': '203780',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 미국나스닥바이오',
#   'nowVal': 21190,
#   'risefall': '2',
#   'changeVal': 10,
#   'changeRate': 0.05,
#   'nav': None,
#   'threeMonthEarnRate': 22.8467,
#   'quant': 19229,
#   'amonut': 408,
#   'marketSum': 318},
#  {'itemcode': '123320',
#   'etfTabCode': 3,
#   'itemname': 'TIGER 레버리지',
#   'nowVal': 26320,
#   'risefall': '2',
#   'changeVal': 460,
#   'changeRate': 1.78,
#   'nav': 26355.0,
#   'threeMonthEarnRate': 92.7692,
#   'quant': 209352,
#   'amonut': 5478,
#   'marketSum': 316},
#  {'itemcode': '354500',
#   'etfTabCode': 1,
#   'itemname': 'KINDEX 코스닥150',
#   'nowVal': 15025,
#   'risefall': '2',
#   'changeVal': 85,
#   'changeRate': 0.57,
#   'nav': 15057.0,
#   'threeMonthEarnRate': 22.1087,
#   'quant': 646,
#   'amonut': 9,
#   'marketSum': 316},
#  {'itemcode': '316670',
#   'etfTabCode': 1,
#   'itemname': 'KOSEF 코스닥150',
#   'nowVal': 7460,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 7489.0,
#   'threeMonthEarnRate': 22.4958,
#   'quant': 532,
#   'amonut': 3,
#   'marketSum': 307},
#  {'itemcode': '276650',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 글로벌4차산업IT(합성 H)',
#   'nowVal': 20730,
#   'risefall': '2',
#   'changeVal': 200,
#   'changeRate': 0.97,
#   'nav': None,
#   'threeMonthEarnRate': 21.1924,
#   'quant': 16485,
#   'amonut': 341,
#   'marketSum': 290},
#  {'itemcode': '250780',
#   'etfTabCode': 3,
#   'itemname': 'TIGER 코스닥150선물인버스',
#   'nowVal': 4540,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.22,
#   'nav': 4545.0,
#   'threeMonthEarnRate': -20.4546,
#   'quant': 894665,
#   'amonut': 4082,
#   'marketSum': 288},
#  {'itemcode': '152870',
#   'etfTabCode': 1,
#   'itemname': '파워 200',
#   'nowVal': 44035,
#   'risefall': '2',
#   'changeVal': 400,
#   'changeRate': 0.92,
#   'nav': 44084.0,
#   'threeMonthEarnRate': 40.2152,
#   'quant': 459,
#   'amonut': 20,
#   'marketSum': 286},
#  {'itemcode': '252420',
#   'etfTabCode': 3,
#   'itemname': 'KBSTAR 200선물인버스2X',
#   'nowVal': 2055,
#   'risefall': '5',
#   'changeVal': -40,
#   'changeRate': -1.91,
#   'nav': 2052.0,
#   'threeMonthEarnRate': -51.1656,
#   'quant': 1330950,
#   'amonut': 2752,
#   'marketSum': 284},
#  {'itemcode': '138230',
#   'etfTabCode': 7,
#   'itemname': 'KOSEF 미국달러선물',
#   'nowVal': 11745,
#   'risefall': '5',
#   'changeVal': -5,
#   'changeRate': -0.04,
#   'nav': 11742.0,
#   'threeMonthEarnRate': -1.6408,
#   'quant': 6072,
#   'amonut': 71,
#   'marketSum': 283},
#  {'itemcode': '361580',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 200TR',
#   'nowVal': 21745,
#   'risefall': '2',
#   'changeVal': 200,
#   'changeRate': 0.93,
#   'nav': 21762.0,
#   'threeMonthEarnRate': 40.2669,
#   'quant': 968,
#   'amonut': 20,
#   'marketSum': 283},
#  {'itemcode': '223190',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 200가치저변동',
#   'nowVal': 10845,
#   'risefall': '2',
#   'changeVal': 60,
#   'changeRate': 0.56,
#   'nav': 10901.0,
#   'threeMonthEarnRate': 31.4442,
#   'quant': 17074,
#   'amonut': 184,
#   'marketSum': 282},
#  {'itemcode': '269540',
#   'etfTabCode': 4,
#   'itemname': 'ARIRANG 미국S&P500(H)',
#   'nowVal': 15620,
#   'risefall': '2',
#   'changeVal': 225,
#   'changeRate': 1.46,
#   'nav': None,
#   'threeMonthEarnRate': 15.578,
#   'quant': 13588,
#   'amonut': 212,
#   'marketSum': 281},
#  {'itemcode': '217780',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 차이나CSI300인버스(합성)',
#   'nowVal': 7270,
#   'risefall': '5',
#   'changeVal': -30,
#   'changeRate': -0.41,
#   'nav': None,
#   'threeMonthEarnRate': -17.4209,
#   'quant': 12928,
#   'amonut': 94,
#   'marketSum': 276},
#  {'itemcode': '225130',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 골드선물 레버리지(합성 H)',
#   'nowVal': 18335,
#   'risefall': '5',
#   'changeVal': -355,
#   'changeRate': -1.9,
#   'nav': None,
#   'threeMonthEarnRate': -5.3911,
#   'quant': 36505,
#   'amonut': 669,
#   'marketSum': 275},
#  {'itemcode': '253250',
#   'etfTabCode': 3,
#   'itemname': 'KOSEF 200선물레버리지',
#   'nowVal': 24950,
#   'risefall': '2',
#   'changeVal': 405,
#   'changeRate': 1.65,
#   'nav': 25000.0,
#   'threeMonthEarnRate': 91.9077,
#   'quant': 8082,
#   'amonut': 200,
#   'marketSum': 274},
#  {'itemcode': '200250',
#   'etfTabCode': 4,
#   'itemname': 'KOSEF 인도Nifty50(합성)',
#   'nowVal': 15420,
#   'risefall': '2',
#   'changeVal': 325,
#   'changeRate': 2.15,
#   'nav': None,
#   'threeMonthEarnRate': 23.1742,
#   'quant': 54093,
#   'amonut': 830,
#   'marketSum': 270},
#  {'itemcode': '363510',
#   'etfTabCode': 6,
#   'itemname': 'SMART KIS단기통안채',
#   'nowVal': 100185,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.01,
#   'nav': 100180.0,
#   'threeMonthEarnRate': 0.1099,
#   'quant': 15,
#   'amonut': 1,
#   'marketSum': 267},
#  {'itemcode': '279530',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 고배당',
#   'nowVal': 8780,
#   'risefall': '2',
#   'changeVal': 75,
#   'changeRate': 0.86,
#   'nav': 8833.0,
#   'threeMonthEarnRate': 14.1639,
#   'quant': 4293,
#   'amonut': 37,
#   'marketSum': 263},
#  {'itemcode': '272910',
#   'etfTabCode': 6,
#   'itemname': 'KINDEX 중장기국공채액티브',
#   'nowVal': 102465,
#   'risefall': '2',
#   'changeVal': 35,
#   'changeRate': 0.03,
#   'nav': 102479.0,
#   'threeMonthEarnRate': -0.0147,
#   'quant': 2001,
#   'amonut': 205,
#   'marketSum': 263},
#  {'itemcode': '139220',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 건설',
#   'nowVal': 2825,
#   'risefall': '2',
#   'changeVal': 80,
#   'changeRate': 2.91,
#   'nav': 2832.0,
#   'threeMonthEarnRate': 43.342,
#   'quant': 557309,
#   'amonut': 1557,
#   'marketSum': 262},
#  {'itemcode': '266420',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 헬스케어',
#   'nowVal': 21810,
#   'risefall': '5',
#   'changeVal': -205,
#   'changeRate': -0.93,
#   'nav': 21935.0,
#   'threeMonthEarnRate': 20.202,
#   'quant': 33351,
#   'amonut': 724,
#   'marketSum': 262},
#  {'itemcode': '227830',
#   'etfTabCode': 1,
#   'itemname': 'ARIRANG 코스피',
#   'nowVal': 32080,
#   'risefall': '2',
#   'changeVal': 285,
#   'changeRate': 0.9,
#   'nav': 32186.0,
#   'threeMonthEarnRate': 37.3552,
#   'quant': 3136,
#   'amonut': 101,
#   'marketSum': 257},
#  {'itemcode': '228800',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 여행레저',
#   'nowVal': 4525,
#   'risefall': '2',
#   'changeVal': 40,
#   'changeRate': 0.89,
#   'nav': 4521.0,
#   'threeMonthEarnRate': 18.9655,
#   'quant': 265360,
#   'amonut': 1193,
#   'marketSum': 257},
#  {'itemcode': '332620',
#   'etfTabCode': 6,
#   'itemname': 'ARIRANG 미국장기우량회사채',
#   'nowVal': 98570,
#   'risefall': '5',
#   'changeVal': -415,
#   'changeRate': -0.42,
#   'nav': None,
#   'threeMonthEarnRate': -1.3996,
#   'quant': 508,
#   'amonut': 49,
#   'marketSum': 256},
#  {'itemcode': '276970',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국S&P고배당커버드콜(합성 H)',
#   'nowVal': 9615,
#   'risefall': '2',
#   'changeVal': 30,
#   'changeRate': 0.31,
#   'nav': None,
#   'threeMonthEarnRate': 12.6321,
#   'quant': 6290,
#   'amonut': 60,
#   'marketSum': 250},
#  {'itemcode': '211900',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 배당성장',
#   'nowVal': 15145,
#   'risefall': '2',
#   'changeVal': 215,
#   'changeRate': 1.44,
#   'nav': 15160.0,
#   'threeMonthEarnRate': 25.6734,
#   'quant': 10676,
#   'amonut': 160,
#   'marketSum': 250},
#  {'itemcode': '244580',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 바이오',
#   'nowVal': 16320,
#   'risefall': '5',
#   'changeVal': -100,
#   'changeRate': -0.61,
#   'nav': 16441.0,
#   'threeMonthEarnRate': 27.2868,
#   'quant': 67065,
#   'amonut': 1085,
#   'marketSum': 248},
#  {'itemcode': '309230',
#   'etfTabCode': 2,
#   'itemname': 'KINDEX 미국WideMoat가치주',
#   'nowVal': 14295,
#   'risefall': '2',
#   'changeVal': 205,
#   'changeRate': 1.45,
#   'nav': None,
#   'threeMonthEarnRate': 16.9294,
#   'quant': 14327,
#   'amonut': 203,
#   'marketSum': 243},
#  {'itemcode': '227540',
# ...
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 57},
#  {'itemcode': '260200',
#   'etfTabCode': 2,
#   'itemname': 'KOSEF 배당바이백Plus',
#   'nowVal': 16260,
#   'risefall': '2',
#   'changeVal': 125,
#   'changeRate': 0.77,
#   'nav': 16256.0,
#   'threeMonthEarnRate': 29.8591,
#   'quant': 74,
#   'amonut': 1,
#   'marketSum': 57},
#  {'itemcode': '217790',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 가격조정',
#   'nowVal': 25560,
#   'risefall': '2',
#   'changeVal': 280,
#   'changeRate': 1.11,
#   'nav': 25574.0,
#   'threeMonthEarnRate': 25.8462,
#   'quant': 5,
#   'amonut': 0,
#   'marketSum': 56},
#  {'itemcode': '300290',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 중소형모멘텀밸류',
#   'nowVal': 12410,
#   'risefall': '2',
#   'changeVal': 180,
#   'changeRate': 1.47,
#   'nav': 12428.0,
#   'threeMonthEarnRate': 25.6291,
#   'quant': 15,
#   'amonut': 0,
#   'marketSum': 56},
#  {'itemcode': '260270',
#   'etfTabCode': 2,
#   'itemname': 'KOSEF 저PBR가중',
#   'nowVal': 15770,
#   'risefall': '2',
#   'changeVal': 230,
#   'changeRate': 1.48,
#   'nav': 15768.0,
#   'threeMonthEarnRate': 34.5454,
#   'quant': 957,
#   'amonut': 14,
#   'marketSum': 55},
#  {'itemcode': '261270',
#   'etfTabCode': 7,
#   'itemname': 'KODEX 미국달러선물인버스',
#   'nowVal': 10295,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.15,
#   'nav': 10316.0,
#   'threeMonthEarnRate': 1.0816,
#   'quant': 113044,
#   'amonut': 1164,
#   'marketSum': 55},
#  {'itemcode': '261920',
#   'etfTabCode': 4,
#   'itemname': 'KINDEX 필리핀MSCI(합성)',
#   'nowVal': 13620,
#   'risefall': '2',
#   'changeVal': 60,
#   'changeRate': 0.44,
#   'nav': None,
#   'threeMonthEarnRate': 9.2227,
#   'quant': 201,
#   'amonut': 2,
#   'marketSum': 54},
#  {'itemcode': '250730',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 차이나HSCEI(H)',
#   'nowVal': 13315,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': None,
#   'threeMonthEarnRate': 16.5936,
#   'quant': 2566,
#   'amonut': 33,
#   'marketSum': 53},
#  {'itemcode': '301410',
#   'etfTabCode': 3,
#   'itemname': 'ARIRANG 코스닥150선물인버스',
#   'nowVal': 7025,
#   'risefall': '5',
#   'changeVal': -30,
#   'changeRate': -0.43,
#   'nav': 7028.0,
#   'threeMonthEarnRate': -20.3725,
#   'quant': 31736,
#   'amonut': 223,
#   'marketSum': 53},
#  {'itemcode': '334690',
#   'etfTabCode': 5,
#   'itemname': 'KBSTAR 팔라듐선물(H)',
#   'nowVal': 13055,
#   'risefall': '5',
#   'changeVal': -85,
#   'changeRate': -0.65,
#   'nav': None,
#   'threeMonthEarnRate': -1.3884,
#   'quant': 12069,
#   'amonut': 157,
#   'marketSum': 52},
#  {'itemcode': '326230',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 내수주플러스',
#   'nowVal': 10845,
#   'risefall': '2',
#   'changeVal': 45,
#   'changeRate': 0.42,
#   'nav': 10917.0,
#   'threeMonthEarnRate': 18.2913,
#   'quant': 2247,
#   'amonut': 24,
#   'marketSum': 52},
#  {'itemcode': '300610',
#   'etfTabCode': 2,
#   'itemname': 'TIGER K게임',
#   'nowVal': 13000,
#   'risefall': '2',
#   'changeVal': 205,
#   'changeRate': 1.6,
#   'nav': 13009.0,
#   'threeMonthEarnRate': 25.997,
#   'quant': 6009,
#   'amonut': 77,
#   'marketSum': 52},
#  {'itemcode': '284990',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200에너지화학',
#   'nowVal': 15050,
#   'risefall': '2',
#   'changeVal': 190,
#   'changeRate': 1.28,
#   'nav': 15043.0,
#   'threeMonthEarnRate': 60.9095,
#   'quant': 7767,
#   'amonut': 116,
#   'marketSum': 51},
#  {'itemcode': '091220',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 은행',
#   'nowVal': 6350,
#   'risefall': '2',
#   'changeVal': 20,
#   'changeRate': 0.32,
#   'nav': 6357.0,
#   'threeMonthEarnRate': 6.1012,
#   'quant': 25537,
#   'amonut': 163,
#   'marketSum': 51},
#  {'itemcode': '292770',
#   'etfTabCode': 6,
#   'itemname': 'KODEX 국채선물3년인버스',
#   'nowVal': 49640,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 49628.0,
#   'threeMonthEarnRate': 0.1412,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 51},
#  {'itemcode': '269370',
#   'etfTabCode': 4,
#   'itemname': 'TIGER S&P글로벌인프라(합성)',
#   'nowVal': 9945,
#   'risefall': '2',
#   'changeVal': 185,
#   'changeRate': 1.9,
#   'nav': None,
#   'threeMonthEarnRate': 12.2355,
#   'quant': 169,
#   'amonut': 1,
#   'marketSum': 50},
#  {'itemcode': '217770',
#   'etfTabCode': 4,
#   'itemname': 'TIGER 원유선물인버스(H)',
#   'nowVal': 8285,
#   'risefall': '5',
#   'changeVal': -110,
#   'changeRate': -1.31,
#   'nav': None,
#   'threeMonthEarnRate': -36.9982,
#   'quant': 1778,
#   'amonut': 14,
#   'marketSum': 50},
#  {'itemcode': '299080',
#   'etfTabCode': 6,
#   'itemname': 'KINDEX 국채선물3년인버스',
#   'nowVal': 99170,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 99156.0,
#   'threeMonthEarnRate': 0.0252,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 50},
#  {'itemcode': '333950',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG KS로우사이즈가중TR',
#   'nowVal': 16465,
#   'risefall': '2',
#   'changeVal': 255,
#   'changeRate': 1.57,
#   'nav': 16462.0,
#   'threeMonthEarnRate': 34.3555,
#   'quant': 222,
#   'amonut': 3,
#   'marketSum': 49},
#  {'itemcode': '292340',
#   'etfTabCode': 2,
#   'itemname': '마이티 200커버드콜ATM레버리지',
#   'nowVal': 9840,
#   'risefall': '2',
#   'changeVal': 95,
#   'changeRate': 0.97,
#   'nav': 9929.0,
#   'threeMonthEarnRate': 20.7558,
#   'quant': 183,
#   'amonut': 1,
#   'marketSum': 49},
#  {'itemcode': '275750',
#   'etfTabCode': 1,
#   'itemname': 'KBSTAR 코스닥150선물인버스',
#   'nowVal': 4685,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 4682.0,
#   'threeMonthEarnRate': -20.5259,
#   'quant': 30321,
#   'amonut': 142,
#   'marketSum': 49},
#  {'itemcode': '307520',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 지주회사',
#   'nowVal': 12265,
#   'risefall': '2',
#   'changeVal': 60,
#   'changeRate': 0.49,
#   'nav': 12259.0,
#   'threeMonthEarnRate': 27.935,
#   'quant': 5749,
#   'amonut': 69,
#   'marketSum': 49},
#  {'itemcode': '261260',
#   'etfTabCode': 7,
#   'itemname': 'KODEX 미국달러선물인버스2X',
#   'nowVal': 10080,
#   'risefall': '2',
#   'changeVal': 40,
#   'changeRate': 0.4,
#   'nav': 10084.0,
#   'threeMonthEarnRate': 2.2403,
#   'quant': 6221,
#   'amonut': 62,
#   'marketSum': 48},
#  {'itemcode': '290080',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200고배당커버드콜ATM',
#   'nowVal': 6865,
#   'risefall': '2',
#   'changeVal': 95,
#   'changeRate': 1.4,
#   'nav': 6856.0,
#   'threeMonthEarnRate': -5.9723,
#   'quant': 67,
#   'amonut': 0,
#   'marketSum': 48},
#  {'itemcode': '299070',
#   'etfTabCode': 6,
#   'itemname': 'KINDEX 국채선물10년인버스',
#   'nowVal': 94000,
#   'risefall': '3',
#   'changeVal': 0,
#   'changeRate': 0.0,
#   'nav': 94059.0,
#   'threeMonthEarnRate': 1.1133,
#   'quant': 0,
#   'amonut': 0,
#   'marketSum': 47},
#  {'itemcode': '291610',
#   'etfTabCode': 1,
#   'itemname': 'KOSEF 코스닥150선물',
#   'nowVal': 9750,
#   'risefall': '2',
#   'changeVal': 35,
#   'changeRate': 0.36,
#   'nav': 9734.0,
#   'threeMonthEarnRate': 23.2868,
#   'quant': 3151,
#   'amonut': 30,
#   'marketSum': 47},
#  {'itemcode': '244670',
#   'etfTabCode': 2,
#   'itemname': 'KODEX 밸류Plus',
#   'nowVal': 9285,
#   'risefall': '2',
#   'changeVal': 110,
#   'changeRate': 1.2,
#   'nav': 9324.0,
#   'threeMonthEarnRate': 26.5517,
#   'quant': 557,
#   'amonut': 5,
#   'marketSum': 46},
#  {'itemcode': '291660',
#   'etfTabCode': 4,
#   'itemname': 'KODEX China H선물인버스(H)',
#   'nowVal': 9140,
#   'risefall': '2',
#   'changeVal': 40,
#   'changeRate': 0.44,
#   'nav': None,
#   'threeMonthEarnRate': -16.0517,
#   'quant': 114,
#   'amonut': 1,
#   'marketSum': 46},
#  {'itemcode': '252410',
#   'etfTabCode': 3,
#   'itemname': 'KBSTAR 200선물인버스',
#   'nowVal': 5000,
#   'risefall': '5',
#   'changeVal': -50,
#   'changeRate': -0.99,
#   'nav': 4990.0,
#   'threeMonthEarnRate': -29.3213,
#   'quant': 14883,
#   'amonut': 74,
#   'marketSum': 45},
#  {'itemcode': '252720',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 모멘텀밸류',
#   'nowVal': 14720,
#   'risefall': '2',
#   'changeVal': 125,
#   'changeRate': 0.86,
#   'nav': 14783.0,
#   'threeMonthEarnRate': 37.6886,
#   'quant': 1165,
#   'amonut': 17,
#   'marketSum': 44},
#  {'itemcode': '295820',
#   'etfTabCode': 1,
#   'itemname': 'ARIRANG 200동일가중',
#   'nowVal': 11000,
#   'risefall': '2',
#   'changeVal': 180,
#   'changeRate': 1.66,
#   'nav': 10994.0,
#   'threeMonthEarnRate': 29.1169,
#   'quant': 193,
#   'amonut': 2,
#   'marketSum': 44},
#  {'itemcode': '304670',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 미국채울트라30년선물인버스(H)',
#   'nowVal': 7300,
#   'risefall': '2',
#   'changeVal': 30,
#   'changeRate': 0.41,
#   'nav': None,
#   'threeMonthEarnRate': 3.1937,
#   'quant': 1399,
#   'amonut': 10,
#   'marketSum': 44},
#  {'itemcode': '271050',
#   'etfTabCode': 5,
#   'itemname': 'KODEX WTI원유선물인버스(H)',
#   'nowVal': 11655,
#   'risefall': '5',
#   'changeVal': -145,
#   'changeRate': -1.23,
#   'nav': None,
#   'threeMonthEarnRate': -36.0607,
#   'quant': 14670,
#   'amonut': 170,
#   'marketSum': 44},
#  {'itemcode': '287330',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200생활소비재',
#   'nowVal': 8895,
#   'risefall': '2',
#   'changeVal': 65,
#   'changeRate': 0.74,
#   'nav': 8894.0,
#   'threeMonthEarnRate': 14.3782,
#   'quant': 161,
#   'amonut': 1,
#   'marketSum': 43},
#  {'itemcode': '291620',
#   'etfTabCode': 3,
#   'itemname': 'KOSEF 코스닥150선물인버스',
#   'nowVal': 8040,
#   'risefall': '5',
#   'changeVal': -35,
#   'changeRate': -0.43,
#   'nav': 8040.0,
#   'threeMonthEarnRate': -20.1681,
#   'quant': 7536,
#   'amonut': 60,
#   'marketSum': 43},
#  {'itemcode': '227560',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 생활소비재',
#   'nowVal': 11680,
#   'risefall': '2',
#   'changeVal': 65,
#   'changeRate': 0.56,
#   'nav': 11676.0,
#   'threeMonthEarnRate': 15.0,
#   'quant': 14697,
#   'amonut': 171,
#   'marketSum': 42},
#  {'itemcode': '321410',
#   'etfTabCode': 7,
#   'itemname': 'KODEX 멀티에셋하이인컴(H)',
#   'nowVal': 10400,
#   'risefall': '2',
#   'changeVal': 45,
#   'changeRate': 0.43,
#   'nav': None,
#   'threeMonthEarnRate': 6.2051,
#   'quant': 913,
#   'amonut': 9,
#   'marketSum': 42},
#  {'itemcode': '227550',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 산업재',
#   'nowVal': 5920,
#   'risefall': '2',
#   'changeVal': 80,
#   'changeRate': 1.37,
#   'nav': 5952.0,
#   'threeMonthEarnRate': 34.5622,
#   'quant': 2819,
#   'amonut': 16,
#   'marketSum': 41},
#  {'itemcode': '292570',
#   'etfTabCode': 7,
#   'itemname': 'TIGER 일본엔선물레버리지',
#   'nowVal': 10355,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.1,
#   'nav': 10335.0,
#   'threeMonthEarnRate': -3.9389,
#   'quant': 219,
#   'amonut': 2,
#   'marketSum': 41},
#  {'itemcode': '267490',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국장기국채선물레버리지(합성 H)',
#   'nowVal': 13575,
#   'risefall': '5',
#   'changeVal': -70,
#   'changeRate': -0.51,
#   'nav': None,
#   'threeMonthEarnRate': -6.0586,
#   'quant': 505,
#   'amonut': 6,
#   'marketSum': 41},
#  {'itemcode': '253240',
#   'etfTabCode': 3,
#   'itemname': 'KOSEF 200선물인버스',
#   'nowVal': 5005,
#   'risefall': '5',
#   'changeVal': -50,
#   'changeRate': -0.99,
#   'nav': 4986.0,
#   'threeMonthEarnRate': -29.4488,
#   'quant': 16302,
#   'amonut': 81,
#   'marketSum': 41},
#  {'itemcode': '278420',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG ESG우수기업',
#   'nowVal': 8995,
#   'risefall': '2',
#   'changeVal': 120,
#   'changeRate': 1.35,
#   'nav': 9016.0,
#   'threeMonthEarnRate': 17.2391,
#   'quant': 2876,
#   'amonut': 25,
#   'marketSum': 40},
#  {'itemcode': '267450',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국장기국채선물인버스(H)',
#   'nowVal': 7915,
#   'risefall': '2',
#   'changeVal': 15,
#   'changeRate': 0.19,
#   'nav': None,
#   'threeMonthEarnRate': 2.4643,
#   'quant': 11,
#   'amonut': 0,
#   'marketSum': 40},
#  {'itemcode': '300280',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 중소형모멘텀로우볼',
#   'nowVal': 11185,
#   'risefall': '2',
#   'changeVal': 215,
#   'changeRate': 1.96,
#   'nav': 11199.0,
#   'threeMonthEarnRate': 21.9566,
#   'quant': 5,
#   'amonut': 0,
#   'marketSum': 39},
#  {'itemcode': '140570',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 수출주',
#   'nowVal': 13035,
#   'risefall': '2',
#   'changeVal': 195,
#   'changeRate': 1.52,
#   'nav': 13036.0,
#   'threeMonthEarnRate': 42.3503,
#   'quant': 125,
#   'amonut': 1,
#   'marketSum': 39},
#  {'itemcode': '295020',
#   'etfTabCode': 6,
#   'itemname': 'KBSTAR 국채선물10년인버스',
#   'nowVal': 46895,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.05,
#   'nav': 46877.0,
#   'threeMonthEarnRate': 1.0891,
#   'quant': 6,
#   'amonut': 0,
#   'marketSum': 38},
#  {'itemcode': '292580',
#   'etfTabCode': 7,
#   'itemname': 'TIGER 일본엔선물인버스',
#   'nowVal': 9410,
#   'risefall': '5',
#   'changeVal': -55,
#   'changeRate': -0.58,
#   'nav': 9468.0,
#   'threeMonthEarnRate': 1.7741,
#   'quant': 10001,
#   'amonut': 94,
#   'marketSum': 38},
#  {'itemcode': '301400',
#   'etfTabCode': 1,
#   'itemname': 'ARIRANG 코스닥150',
#   'nowVal': 14960,
#   'risefall': '2',
#   'changeVal': 55,
#   'changeRate': 0.37,
#   'nav': 15047.0,
#   'threeMonthEarnRate': 22.3225,
#   'quant': 4506,
#   'amonut': 67,
#   'marketSum': 37},
#  {'itemcode': '269530',
#   'etfTabCode': 4,
#   'itemname': 'ARIRANG S&P글로벌인프라',
#   'nowVal': 10430,
#   'risefall': '2',
#   'changeVal': 115,
#   'changeRate': 1.11,
#   'nav': None,
#   'threeMonthEarnRate': 9.734,
#   'quant': 1895,
#   'amonut': 19,
#   'marketSum': 37},
#  {'itemcode': '139240',
#   'etfTabCode': 2,
#   'itemname': 'TIGER 200 철강소재',
#   'nowVal': 7565,
#   'risefall': '5',
#   'changeVal': -10,
#   'changeRate': -0.13,
#   'nav': 7583.0,
#   'threeMonthEarnRate': 26.1448,
#   'quant': 8725,
#   'amonut': 65,
#   'marketSum': 36},
#  {'itemcode': '291680',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 차이나H선물인버스(H)',
#   'nowVal': 8980,
#   'risefall': '2',
#   'changeVal': 50,
#   'changeRate': 0.56,
#   'nav': None,
#   'threeMonthEarnRate': -16.4249,
#   'quant': 158,
#   'amonut': 1,
#   'marketSum': 36},
#  {'itemcode': '280940',
#   'etfTabCode': 4,
#   'itemname': 'KODEX 골드선물인버스(H)',
#   'nowVal': 7140,
#   'risefall': '2',
#   'changeVal': 85,
#   'changeRate': 1.2,
#   'nav': None,
#   'threeMonthEarnRate': 0.427,
#   'quant': 4442,
#   'amonut': 31,
#   'marketSum': 36},
#  {'itemcode': '140580',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 우량업종',
#   'nowVal': 11725,
#   'risefall': '2',
#   'changeVal': 100,
#   'changeRate': 0.86,
#   'nav': 11740.0,
#   'threeMonthEarnRate': 25.4045,
#   'quant': 618,
#   'amonut': 7,
#   'marketSum': 35},
#  {'itemcode': '292590',
#   'etfTabCode': 7,
#   'itemname': 'TIGER 일본엔선물인버스2X',
#   'nowVal': 8510,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.29,
#   'nav': 8510.0,
#   'threeMonthEarnRate': 2.9108,
#   'quant': 255,
#   'amonut': 2,
#   'marketSum': 34},
#  {'itemcode': '139310',
#   'etfTabCode': 5,
#   'itemname': 'TIGER 금속선물(H)',
#   'nowVal': 5595,
#   'risefall': '5',
#   'changeVal': -5,
#   'changeRate': -0.09,
#   'nav': None,
#   'threeMonthEarnRate': 11.665,
#   'quant': 1541,
#   'amonut': 8,
#   'marketSum': 34},
#  {'itemcode': '309170',
#   'etfTabCode': 2,
#   'itemname': 'ARIRANG KRX300IT',
#   'nowVal': 20715,
#   'risefall': '2',
#   'changeVal': 135,
#   'changeRate': 0.66,
#   'nav': 20712.0,
#   'threeMonthEarnRate': 52.614,
#   'quant': 283,
#   'amonut': 5,
#   'marketSum': 29},
#  {'itemcode': '287310',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200경기소비재',
#   'nowVal': 12715,
#   'risefall': '2',
#   'changeVal': 485,
#   'changeRate': 3.97,
#   'nav': 12766.0,
#   'threeMonthEarnRate': 39.9313,
#   'quant': 1774,
#   'amonut': 22,
#   'marketSum': 25},
#  {'itemcode': '284980',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200금융',
#   'nowVal': 7705,
#   'risefall': '2',
#   'changeVal': 35,
#   'changeRate': 0.46,
#   'nav': 7707.0,
#   'threeMonthEarnRate': 8.4865,
#   'quant': 4289,
#   'amonut': 33,
#   'marketSum': 23},
#  {'itemcode': '285010',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200중공업',
#   'nowVal': 8485,
#   'risefall': '2',
#   'changeVal': 20,
#   'changeRate': 0.24,
#   'nav': 8481.0,
#   'threeMonthEarnRate': 16.7586,
#   'quant': 282,
#   'amonut': 2,
#   'marketSum': 22},
#  {'itemcode': '334700',
#   'etfTabCode': 5,
#   'itemname': 'KBSTAR 팔라듐선물인버스(H)',
#   'nowVal': 5495,
#   'risefall': '2',
#   'changeVal': 30,
#   'changeRate': 0.55,
#   'nav': None,
#   'threeMonthEarnRate': -1.5316,
#   'quant': 1816,
#   'amonut': 9,
#   'marketSum': 22},
#  {'itemcode': '267500',
#   'etfTabCode': 4,
#   'itemname': 'KBSTAR 미국장기국채선물인버스2X(합성 H)',
#   'nowVal': 6030,
#   'risefall': '2',
#   'changeVal': 30,
#   'changeRate': 0.5,
#   'nav': None,
#   'threeMonthEarnRate': 4.8951,
#   'quant': 4614,
#   'amonut': 27,
#   'marketSum': 18},
#  {'itemcode': '285020',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200철강소재',
#   'nowVal': 7245,
#   'risefall': '2',
#   'changeVal': 25,
#   'changeRate': 0.35,
#   'nav': 7246.0,
#   'threeMonthEarnRate': 25.5652,
#   'quant': 3443,
#   'amonut': 24,
#   'marketSum': 17},
#  {'itemcode': '287320',
#   'etfTabCode': 2,
#   'itemname': 'KBSTAR 200산업재',
#   'nowVal': 10750,
#   'risefall': '2',
#   'changeVal': 220,
#   'changeRate': 2.09,
#   'nav': 10776.0,
#   'threeMonthEarnRate': 33.1226,
#   'quant': 47,
#   'amonut': 0,
#   'marketSum': 13}]

# %%
len(etfItemList)
# Out:
# 469

# %% [markdown]
# <br>
#
# ### 7.3.6 JSON 데이터를 pandas의 데이터프레임 형태로 만들기

# %%
df = pd.DataFrame(etfItemList)
df.shape
# Out:
# (469, 12)

# %%
df.head()
# Out:
#   itemcode  etfTabCode          itemname  nowVal risefall  changeVal  \
# 0   069500           1         KODEX 200   43130        2        355
# 1   102110           1         TIGER 200   42970        2        360
# 2   252670           3  KODEX 200선물인버스2X    2055        5        -35
# 3   122630           3        KODEX 레버리지   27825        2        475
# 4   102780           2        KODEX 삼성그룹   10530        2         70
#
#    changeRate      nav  threeMonthEarnRate      quant   amonut  marketSum
# 0        0.83  43214.0             39.9522    8521906   366352      62625
# 1        0.84  43038.0             39.9710    1650818    70651      31347
# 2       -1.67   2051.0            -51.2821  642008913  1329284      20227
# 3        1.74  28022.0             92.0646   46157932  1275107      19088
# 4        0.67  10545.0             37.6315     612363     6415      18522

# %%
df.tail()
# Out:
#     itemcode  etfTabCode                    itemname  nowVal risefall  \
# 464   285010           2               KBSTAR 200중공업    8485        2
# 465   334700           5          KBSTAR 팔라듐선물인버스(H)    5495        2
# 466   267500           4  KBSTAR 미국장기국채선물인버스2X(합성 H)    6030        2
# 467   285020           2              KBSTAR 200철강소재    7245        2
# 468   287320           2               KBSTAR 200산업재   10750        2
#
#      changeVal  changeRate      nav  threeMonthEarnRate  quant  amonut  \
# 464         20        0.24   8481.0             16.7586    282       2
# 465         30        0.55      NaN             -1.5316   1816       9
# 466         30        0.50      NaN              4.8951   4614      27
# 467         25        0.35   7246.0             25.5652   3443      24
# 468        220        2.09  10776.0             33.1226     47       0
#
#      marketSum
# 464         22
# 465         22
# 466         18
# 467         17
# 468         13

# %% [markdown]
# <br>
#
# ## 7.4 파일 저장

# %% [markdown]
# ### 7.4.1 파일명 만들기
#
# - 오늘 날짜를 가져오기 위해 `datetime` 사용

# %%
import datetime
today = datetime.datetime.today()
today = today.strftime('%Y-%m-%d')
today
# Out:
# '2021-02-03'

# %% [markdown]
# - f-string 방식으로 파일 이름 만들기

# %%
filename = f'etf_{today}_raw.csv'
filename
# Out:
# 'etf_2021-02-03_raw.csv'

# %% [markdown]
# <br>
#
# ### 7.4.2 파일로 저장하고 불러오기

# %%
df.to_csv(filename, index=False)

# %%
pd.read_csv(filename, dtype={'itemcode': np.object}) # 종목코드 숫자형 변환 방지
# Out:
#     itemcode  etfTabCode                    itemname  nowVal  risefall  \
# 0     069500           1                   KODEX 200   43130         2
# 1     102110           1                   TIGER 200   42970         2
# 2     252670           3            KODEX 200선물인버스2X    2055         5
# 3     122630           3                  KODEX 레버리지   27825         2
# 4     102780           2                  KODEX 삼성그룹   10530         2
# ..       ...         ...                         ...     ...       ...
# 464   285010           2               KBSTAR 200중공업    8485         2
# 465   334700           5          KBSTAR 팔라듐선물인버스(H)    5495         2
# 466   267500           4  KBSTAR 미국장기국채선물인버스2X(합성 H)    6030         2
# 467   285020           2              KBSTAR 200철강소재    7245         2
# 468   287320           2               KBSTAR 200산업재   10750         2
#
#      changeVal  changeRate      nav  threeMonthEarnRate      quant   amonut  \
# 0          355        0.83  43214.0             39.9522    8521906   366352
# 1          360        0.84  43038.0             39.9710    1650818    70651
# 2          -35       -1.67   2051.0            -51.2821  642008913  1329284
# 3          475        1.74  28022.0             92.0646   46157932  1275107
# 4           70        0.67  10545.0             37.6315     612363     6415
# ..         ...         ...      ...                 ...        ...      ...
# 464         20        0.24   8481.0             16.7586        282        2
# 465         30        0.55      NaN             -1.5316       1816        9
# 466         30        0.50      NaN              4.8951       4614       27
# 467         25        0.35   7246.0             25.5652       3443       24
# 468        220        2.09  10776.0             33.1226         47        0
#
#      marketSum
# 0        62625
# 1        31347
# 2        20227
# 3        19088
# 4        18522
# ..         ...
# 464         22
# 465         22
# 466         18
# 467         17
# 468         13
#
# [469 rows x 12 columns]
